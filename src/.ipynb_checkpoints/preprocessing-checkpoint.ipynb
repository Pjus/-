# %%
import dart_fss as dart

import pandas as pd

# %%
api_key='35d444d5a2ca8c271de34c8d296baf7474c37035' 
dart.set_api_key(api_key=api_key)
# Out:
# '35d444d5a2ca8c271de34c8d296baf7474c37035'

# %%
# DART 에 공시된 회사 리스트 불러오기
corp_list = dart.corp.CorpList()
# Out:
# Output()
# Output()
# Output()

# %%
samsung1 = corp_list.find_by_stock_code('002790')
samsung1
# Out:
# [00154462]아모레퍼시픽그룹

# %%
# 삼성전자 검색
samsung = corp_list.find_by_corp_name('현대건설', exactly=True)[0]
samsung
# Out:
# [00164478]현대건설

# %%
# 2018년부터 연간 연결재무제표 불러오기
fs = samsung.extract_fs(bgn_de='19870101', report_tp='quarter')
# Out:
# Output()
# Output()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-10dfab52fa15> in <module>
#       1 # 2018년부터 연간 연결재무제표 불러오기
# ----> 2 fs = samsung.extract_fs(bgn_de='19870101', report_tp='quarter')
#
# ~\AppData\Roaming\Python\Python37\site-packages\dart_fss\corp\corp.py in extract_fs(self, bgn_de, end_de, fs_tp, separate, report_tp, lang, separator)
#     225
#     226          """
# --> 227         return extract(self.corp_code, bgn_de, end_de, fs_tp, separate, report_tp, lang, separator)
#
# ~\AppData\Roaming\Python\Python37\site-packages\dart_fss\fs\extract.py in extract(corp_code, bgn_de, end_de, fs_tp, separate, report_tp, lang, separator)
#    1053             # 가장 최근 보고서의 경우 XBRL 파일을 이용하여 재무제표 검색
#    1054             latest_report = reports[idx]
# -> 1055             latest_xbrl = latest_report.xbrl
#    1056             # XBRL 파일이 존재할 때
#    1057             if latest_xbrl is not None:
#
# ~\AppData\Roaming\Python\Python37\site-packages\dart_fss\filings\reports.py in xbrl(self)
#     366                 try:
#     367                     file_path = download_xbrl(path=path, rcept_no=self.rcept_no)
# --> 368                     self._xbrl = get_xbrl_from_file(file_path)
#     369                 except FileNotFoundError:
#     370                     xbrl_attached = self._get_xbrl()
#
# ~\AppData\Roaming\Python\Python37\site-packages\dart_fss\xbrl\xbrl.py in get_xbrl_from_file(file_path)
#      37         if not os.path.exists(arelle_app_dir):
#      38             os.makedirs(arelle_app_dir)
# ---> 39     model_xbrl = Cntlr.Cntlr().modelManager.load(file_path)
#      40     filename = file_path.split('\\')[-1]
#      41     xbrl = DartXbrl(filename, model_xbrl)
#
# C:\ProgramData\Anaconda3\lib\site-packages\arelle\ModelManager.py in load(self, filesource, nextaction, taxonomyPackages, **kwargs)
#     156                 break # custom loader did the loading
#     157         if modelXbrl is None:  # use default xbrl loader
# --> 158             modelXbrl = ModelXbrl.load(self, filesource, nextaction, **kwargs)
#     159         self.modelXbrl = modelXbrl
#     160         self.loadedModelXbrls.append(self.modelXbrl)
#
# C:\ProgramData\Anaconda3\lib\site-packages\arelle\ModelXbrl.py in load(modelManager, url, nextaction, base, useFileSource, errorCaptureLevel, **kwargs)
#      67         modelXbrl.closeFileSource= True
#      68
# ---> 69     modelXbrl.modelDocument = ModelDocument.load(modelXbrl, url, base, isEntry=True, **kwargs)
#      70
#      71 #    print('Model Document' + str(modelXbrl.modelDocument))
#
# C:\ProgramData\Anaconda3\lib\site-packages\arelle\ModelDocument.py in load(modelXbrl, uri, base, referringElement, isEntry, isDiscovered, isIncluded, namespace, reloadCache, **kwargs)
#     332                 modelDocument.linkbaseDiscover(rootNode)
#     333         elif _type == Type.INSTANCE:
# --> 334             modelDocument.instanceDiscover(rootNode)
#     335         elif _type == Type.INLINEXBRL:
#     336             # slow
#
# C:\ProgramData\Anaconda3\lib\site-packages\arelle\ModelDocument.py in instanceDiscover(self, xbrlElement)
#    1144
#    1145     def instanceDiscover(self, xbrlElement):
# -> 1146         self.schemaLinkbaseRefsDiscover(xbrlElement)
#    1147         if not self.skipDTS:
#    1148             self.linkbaseDiscover(xbrlElement,inInstance=True) # for role/arcroleRefs and footnoteLinks
#
# C:\ProgramData\Anaconda3\lib\site-packages\arelle\ModelDocument.py in schemaLinkbaseRefsDiscover(self, tree)
#    1007             for element in tree.iterdescendants(tag=refln):
#    1008                 if isinstance(element,ModelObject):
# -> 1009                     self.schemaLinkbaseRefDiscover(element)
#    1010
#    1011     def schemaLinkbaseRefDiscover(self, element):
#
# C:\ProgramData\Anaconda3\lib\site-packages\arelle\ModelDocument.py in schemaLinkbaseRefDiscover(self, element)
#    1010
#    1011     def schemaLinkbaseRefDiscover(self, element):
# -> 1012         return self.discoverHref(element, urlRewritePluginClass="ModelDocument.InstanceSchemaRefRewriter")
#    1013
#    1014     def linkbasesDiscover(self, tree):
#
# C:\ProgramData\Anaconda3\lib\site-packages\arelle\ModelDocument.py in discoverHref(self, element, nonDTS, urlRewritePluginClass)
#    1130                     for pluginMethod in pluginClassMethods(urlRewritePluginClass):
#    1131                         url = pluginMethod(self, url)
# -> 1132                 doc = _newDoc(self.modelXbrl, url, isDiscovered=not nonDTS, base=self.baseForElement(element), referringElement=element)
#    1133                 if not nonDTS and doc is not None and doc not in self.referencesDocument:
#    1134                     self.referencesDocument[doc] = ModelDocumentReference("href", element)
#
# C:\ProgramData\Anaconda3\lib\site-packages\arelle\ModelDocument.py in load(modelXbrl, uri, base, referringElement, isEntry, isDiscovered, isIncluded, namespace, reloadCache, **kwargs)
#     325         elif _type == Type.SCHEMA:
#     326             # slow
# --> 327             modelDocument.schemaDiscover(rootNode, isIncluded, namespace)
#     328             #print("SCHEMA: {0:.2f} | {1} {2}".format(time()-s, isIncluded, namespace))
#     329         elif _type == Type.LINKBASE:
#
# C:\ProgramData\Anaconda3\lib\site-packages\arelle\ModelDocument.py in schemaDiscover(self, rootElement, isIncluded, namespace)
#     870         # self.definesUTR = any(ns == XbrlConst.utr for ns in rootElement.nsmap.values())
#     871         try:
# --> 872             self.schemaDiscoverChildElements(rootElement)
#     873         except (ValueError, LookupError) as err:
#     874             self.modelXbrl.modelManager.addToLog("discovery: {0} error {1}".format(
#
# C:\ProgramData\Anaconda3\lib\site-packages\arelle\ModelDocument.py in schemaDiscoverChildElements(self, parentModelObject)
#     907                             self.linkbaseDiscover(modelObject)
#     908                 # recurse to children
# --> 909                 self.schemaDiscoverChildElements(modelObject)
#     910
#     911
#
# C:\ProgramData\Anaconda3\lib\site-packages\arelle\ModelDocument.py in schemaDiscoverChildElements(self, parentModelObject)
#     907                             self.linkbaseDiscover(modelObject)
#     908                 # recurse to children
# --> 909                 self.schemaDiscoverChildElements(modelObject)
#     910
#     911
#
# C:\ProgramData\Anaconda3\lib\site-packages\arelle\ModelDocument.py in schemaDiscoverChildElements(self, parentModelObject)
#     903                             self.modelXbrl.arcroleTypes[modelObject.arcroleURI].append(modelObject)
#     904                         elif ln == "linkbaseRef":
# --> 905                             self.schemaLinkbaseRefDiscover(modelObject)
#     906                         elif ln == "linkbase":
#     907                             self.linkbaseDiscover(modelObject)
#
# C:\ProgramData\Anaconda3\lib\site-packages\arelle\ModelDocument.py in schemaLinkbaseRefDiscover(self, element)
#    1010
#    1011     def schemaLinkbaseRefDiscover(self, element):
# -> 1012         return self.discoverHref(element, urlRewritePluginClass="ModelDocument.InstanceSchemaRefRewriter")
#    1013
#    1014     def linkbasesDiscover(self, tree):
#
# C:\ProgramData\Anaconda3\lib\site-packages\arelle\ModelDocument.py in discoverHref(self, element, nonDTS, urlRewritePluginClass)
#    1130                     for pluginMethod in pluginClassMethods(urlRewritePluginClass):
#    1131                         url = pluginMethod(self, url)
# -> 1132                 doc = _newDoc(self.modelXbrl, url, isDiscovered=not nonDTS, base=self.baseForElement(element), referringElement=element)
#    1133                 if not nonDTS and doc is not None and doc not in self.referencesDocument:
#    1134                     self.referencesDocument[doc] = ModelDocumentReference("href", element)
#
# C:\ProgramData\Anaconda3\lib\site-packages\arelle\ModelDocument.py in load(modelXbrl, uri, base, referringElement, isEntry, isDiscovered, isIncluded, namespace, reloadCache, **kwargs)
#     330             # slow
#     331             if not AWESOME_MODS:
# --> 332                 modelDocument.linkbaseDiscover(rootNode)
#     333         elif _type == Type.INSTANCE:
#     334             modelDocument.instanceDiscover(rootNode)
#
# C:\ProgramData\Anaconda3\lib\site-packages\arelle\ModelDocument.py in linkbaseDiscover(self, linkbaseElement, inInstance)
#    1051                                 self.modelXbrl.baseSets[baseSetKey].append(lbElement)
#    1052                         linkElementSequence = 0
# -> 1053                         for linkElement in lbElement.iterchildren():
#    1054                             if isinstance(linkElement,ModelObject):
#    1055                                 linkElementSequence += 1
#
# src/lxml/etree.pyx in lxml.etree._ElementMatchIterator.__next__()
#
# src/lxml/etree.pyx in lxml.etree._ElementMatchIterator._storeNext()
#
# src/lxml/etree.pyx in lxml.etree._elementFactory()
#
# src/lxml/classlookup.pxi in lxml.etree._parser_class_lookup()
#
# src/lxml/classlookup.pxi in lxml.etree._custom_class_lookup()
#
# C:\ProgramData\Anaconda3\lib\site-packages\arelle\ModelObjectFactory.py in lookup(self, node_type, document, ns, ln)
#     112             return self.modelXbrl.matchSubstitutionGroup(
#     113                                         qnameNsLocalName(ns, ln),
# --> 114                                         elementSubstitutionModelClass)
#     115         elif node_type == "comment":
#     116             from arelle.ModelObject import ModelComment
#
# C:\ProgramData\Anaconda3\lib\site-packages\arelle\ModelXbrl.py in matchSubstitutionGroup(self, elementQname, subsGrpMatchTable)
#     417         if elementQname in subsGrpMatchTable:
#     418             return subsGrpMatchTable[elementQname] # head of substitution group
# --> 419         elementMdlObj = self.qnameConcepts.get(elementQname)
#     420         if elementMdlObj is not None:
#     421             subsGrpMdlObj = elementMdlObj.substitutionGroup
#
# C:\ProgramData\Anaconda3\lib\site-packages\arelle\ModelValue.py in __eq__(self, other)
#     150         try:
#     151             return (self.qnameValueHash == other.qnameValueHash and
# --> 152                     self.localName == other.localName and self.namespaceURI == other.namespaceURI)
#     153         except AttributeError:
#     154             return False
#
# KeyboardInterrupt:

# %%
fs[3]
# Out:
#    [D520000] Statement of cash flows, indirect method - Consolidated financial statements (Unit: KRW)  \
#                                                                                            concept_id
# 0    ifrs-full_CashFlowsFromUsedInOperatingActivities
# 1   entity00126380_udf_CF_201710211099539_CashFlow...
# 2   entity00126380_udf_CF_201710211092510_udf_CF_2...
# 3   entity00126380_udf_CF_2017102110929616_udf_CF_...
# 4   entity00126380_udf_CF_2017102110934928_udf_CF_...
# 5   ifrs-full_InterestReceivedClassifiedAsOperatin...
# 6   ifrs-full_InterestPaidClassifiedAsOperatingAct...
# 7   ifrs-full_DividendsReceivedClassifiedAsOperati...
# 8   ifrs-full_IncomeTaxesPaidRefundClassifiedAsOpe...
# 9    ifrs-full_CashFlowsFromUsedInInvestingActivities
# 10  entity00126380_udf_CF_2017102110167395_CashFlo...
# 11  entity00126380_udf_CF_201987152650384_CashFlow...
# 12  entity00126380_udf_CF_2019726153251267_CashFlo...
# 13  entity00126380_udf_CF_2020210125720111_CashFlo...
# 14  dart_ProceedsFromSalesOfLongTermFinancialInstr...
# 15        dart_PurchaseOfLongTermFinancialInstruments
# 16  entity00126380_udf_CF_202021013058237_CashFlow...
# 17  entity00126380_udf_CF_2020210125811828_CashFlo...
# 18       dart_PurchaseOfFinancialAssetsHeldToMaturity
# 19  entity00126380_udf_CF_201972615318915_CashFlow...
# 20  entity00126380_udf_CF_2018510204028298_CashFlo...
# 21  entity00126380_udf_CF_2018510204038291_CashFlo...
# 22  entity00126380_udf_CF_2018510204040276_CashFlo...
# 23  entity00126380_udf_CF_2018510204036276_CashFlo...
# 24  entity00126380_udf_CF_2018510204025664_CashFlo...
# 25  entity00126380_udf_CF_20171021101629105_CashFl...
# 26  entity00126380_udf_CF_20171021101629633_CashFl...
# 27  ifrs-full_ProceedsFromSalesOfPropertyPlantAndE...
# 28  ifrs-full_PurchaseOfPropertyPlantAndEquipmentC...
# 29  ifrs-full_ProceedsFromSalesOfIntangibleAssetsC...
# 30  ifrs-full_PurchaseOfIntangibleAssetsClassified...
# 31  entity00126380_udf_CF_20171021101626447_CashFl...
# 32  entity00126380_udf_CF_202021013532484_CashFlow...
# 33  entity00126380_udf_CF_20171021101625672_CashFl...
# 34   ifrs-full_CashFlowsFromUsedInFinancingActivities
# 35  entity00126380_udf_CF_20171021102249949_CashFl...
# 36                   dart_AcquisitionOfTreasuryShares
# 37                dart_ProceedsFromLongTermBorrowings
# 38                dart_RepaymentsOfLongTermBorrowings
# 39  ifrs-full_DividendsPaidClassifiedAsFinancingAc...
# 40  entity00126380_udf_CF_20171021102253395_CashFl...
# 41  ifrs-full_EffectOfExchangeRateChangesOnCashAnd...
# 42  ifrs-full_IncreaseDecreaseInCashAndCashEquival...
# 43   dart_CashAndCashEquivalentsAtBeginningOfPeriodCf
# 44         dart_CashAndCashEquivalentsAtEndOfPeriodCf
#
#                               \
#                     label_ko
# 0                  영업활동 현금흐름
# 1              영업에서 창출된 현금흐름
# 2                      당기순이익
# 3                         조정
# 4         영업활동으로 인한 자산부채의 변동
# 5                     이자의 수취
# 6                     이자의 지급
# 7                     배당금 수입
# 8                    법인세 납부액
# 9                  투자활동 현금흐름
# 10           단기금융상품의 순감소(증가)
# 11      단기상각후원가금융자산의 순감소(증가)
# 12  단기당기손익-공정가치금융자산의 순감소(증가)
# 13            단기매도가능금융자산의 처분
# 14                장기금융상품의 처분
# 15                장기금융상품의 취득
# 16            장기매도가능금융자산의 처분
# 17            장기매도가능금융자산의 취득
# 18              만기보유금융자산의 취득
# 19             상각후원가금융자산의 처분
# 20             상각후원가금융자산의 취득
# 21       기타포괄손익-공정가치금융자산의 처분
# 22       기타포괄손익-공정가치금융자산의 취득
# 23         당기손익-공정가치금융자산의 처분
# 24         당기손익-공정가치금융자산의 취득
# 25        관계기업 및 공동기업 투자의 처분
# 26        관계기업 및 공동기업 투자의 취득
# 27                  유형자산의 처분
# 28                  유형자산의 취득
# 29                  무형자산의 처분
# 30                  무형자산의 취득
# 31           사업결합으로 인한 현금유출액
# 32            사업양도로 인한 현급유입액
# 33        기타투자활동으로 인한 현금유출입액
# 34                 재무활동 현금흐름
# 35            단기차입금의 순증가(감소)
# 36                  자기주식의 취득
# 37                 장기차입금의 차입
# 38            사채 및 장기차입금의 상환
# 39                   배당금의 지급
# 40                 비지배지분의 증감
# 41          외화환산으로 인한 현금의 변동
# 42             현금및현금성자산의 순증감
# 43              기초의 현금및현금성자산
# 44              기말의 현금및현금성자산
#
#                                                                          \
#                                              label_en            class0
# 0      Cash flows from (used in) operating activities  현금흐름표 [abstract]
# 1                Cash flows from operating activities  현금흐름표 [abstract]
# 2                                              Profit  현금흐름표 [abstract]
# 3                                         Adjustments  현금흐름표 [abstract]
# 4   NEWAccount for Cash flows from operating activ...  현금흐름표 [abstract]
# 5                                   Interest received  현금흐름표 [abstract]
# 6                                       Interest paid  현금흐름표 [abstract]
# 7                                  Dividends received  현금흐름표 [abstract]
# 8                          Income taxes paid (refund)  현금흐름표 [abstract]
# 9      Cash flows from (used in) investing activities  현금흐름표 [abstract]
# 10  Net outflow in financial assets at fair value ...  현금흐름표 [abstract]
# 11  Net increase of financial assets measured at a...  현금흐름표 [abstract]
# 12  Net decrease of short-term financial assets at...  현금흐름표 [abstract]
# 13  the disposal of Available-for-sale financial a...  현금흐름표 [abstract]
# 14  Proceeds from sales of long-term financial ins...  현금흐름표 [abstract]
# 15        Purchase of long-term financial instruments  현금흐름표 [abstract]
# 16  Proceeds from sales of non-current available-f...  현금흐름표 [abstract]
# 17     Purchase of non-current available-for-sale f/s  현금흐름표 [abstract]
# 18  Proceeds from sales of maturity-holding securi...  현금흐름표 [abstract]
# 19  Disposal of Financial Assets Measured at Amort...  현금흐름표 [abstract]
# 20  Purchase of Financial Assets Measured at Amort...  현금흐름표 [abstract]
# 21  Proceeds from disposal of fair value assessmen...  현금흐름표 [abstract]
# 22  Proceeds from acquisition of fair value assess...  현금흐름표 [abstract]
# 23  Proceeds from disposal of fair value assessmen...  현금흐름표 [abstract]
# 24  Proceeds from acquisition of fair value assess...  현금흐름표 [abstract]
# 25  Proceeds from disposal of associates and joint...  현금흐름표 [abstract]
# 26  Acquisition from disposal of associates and jo...  현금흐름표 [abstract]
# 27  Proceeds from sales of property, plant and equ...  현금흐름표 [abstract]
# 28          Purchase of property, plant and equipment  현금흐름표 [abstract]
# 29           Proceeds from sales of intangible assets  현금흐름표 [abstract]
# 30                      Purchase of intangible assets  현금흐름표 [abstract]
# 31             Net Cashflow from Business combination  현금흐름표 [abstract]
# 32        Net Cashflow from Business combination(out)  현금흐름표 [abstract]
# 33                                             Others  현금흐름표 [abstract]
# 34     Cash flows from (used in) financing activities  현금흐름표 [abstract]
# 35   Net proceeds(repayment of) short-term borrowings  현금흐름표 [abstract]
# 36                     Acquisition of treasury shares  현금흐름표 [abstract]
# 37                 Proceeds from long term borrowings  현금흐름표 [abstract]
# 38                 Repayments of long term borrowings  현금흐름표 [abstract]
# 39                                     Dividends paid  현금흐름표 [abstract]
# 40                                 Minority interests  현금흐름표 [abstract]
# 41  Effect of exchange rate changes on cash and ca...  현금흐름표 [abstract]
# 42  Net increase (decrease) in cash and cash equiv...  현금흐름표 [abstract]
# 43   Cash and cash equivalents at beginning of period  현금흐름표 [abstract]
# 44         Cash and cash equivalents at end of period  현금흐름표 [abstract]
#
#                                                                     \
#               class1                    class2              class3
# 0          영업활동 현금흐름                      None                None
# 1          영업활동 현금흐름             영업에서 창출된 현금흐름                None
# 2          영업활동 현금흐름             영업에서 창출된 현금흐름               당기순이익
# 3          영업활동 현금흐름             영업에서 창출된 현금흐름                  조정
# 4          영업활동 현금흐름             영업에서 창출된 현금흐름  영업활동으로 인한 자산부채의 변동
# 5          영업활동 현금흐름                    이자의 수취                None
# 6          영업활동 현금흐름                    이자의 지급                None
# 7          영업활동 현금흐름                    배당금 수입                None
# 8          영업활동 현금흐름                   법인세 납부액                None
# 9          투자활동 현금흐름                      None                None
# 10         투자활동 현금흐름           단기금융상품의 순감소(증가)                None
# 11         투자활동 현금흐름      단기상각후원가금융자산의 순감소(증가)                None
# 41    50,753,000,000.0     -19,823,000,000.0     -45,830,000,000.0
# 42                 nan                   nan                  None
# 43                 nan                   nan                  None
# 44                 nan                   nan                  None
#
#        20000101-20001231   19990101-19991231   19980101-19981231  \
#                (연결재무제표,)           (연결재무제표,)           (연결재무제표,)
# 0                    nan                 nan                 nan
# 1                    nan                 nan                 nan
# 2    6,002,881,821,000.0 3,175,307,880,000.0                 nan
# 3                    nan                 nan                 nan
# 4                    nan   179,649,542,000.0 2,027,422,292,000.0
# 5                    nan                 nan                 nan
# 6                    nan                 nan                 nan
# 7                    nan                 nan                 nan
# 8                    nan                 nan                 nan
# 9                    nan                 nan                 nan
# 10   1,269,803,734,000.0   -67,504,336,000.0                 nan
# 11                   nan                 nan                 nan
# 12                   nan                 nan                 nan
# 13                   nan                 nan                 nan
# 14                   nan                 nan                 nan
# 15                   nan                 nan                 nan
# 16                   nan                 nan                 nan
# 17                   nan                 nan                 nan
# 18                   nan                 nan                 nan
# 19                   nan                 nan                 nan
# 20                   nan                 nan                 nan
# 21                   nan                 nan                 nan
# 22                   nan                 nan                 nan
# 23                   nan                 nan                 nan
# 24                   nan                 nan                 nan
# 25                   nan                 nan                 nan
# 26                   nan                 nan                 nan
# 27                   nan                 nan                 nan
# 28                   nan                 nan                 nan
# 29                   nan                 nan                 nan
# 30                   nan   -94,923,780,000.0    94,207,431,000.0
# 31                   nan                 nan                 nan
# 32                   nan                 nan                 nan
# 33                   nan                 nan                 nan
# 34                   nan                 nan                 nan
# 35 108,495,342,268,000.0   897,595,182,000.0                 nan
# 36     557,035,590,000.0                 nan                 nan
# 37     104,233,202,000.0   819,715,632,000.0   637,214,469,000.0
# 38                   nan                 nan                 nan
# 39                   nan                 nan                 nan
# 40                   nan                 nan                 nan
# 41      26,987,881,000.0    56,756,474,000.0    34,834,015,000.0
# 42                   nan                 nan                 nan
# 43                   nan                 nan                 nan
# 44                   nan                 nan                 nan
#
#      19970101-19971231
#              (연결재무제표,)
# 0                  nan
# 1                  nan
# 2                  nan
# 3                  nan
# 4   -642,389,273,000.0
# 5                  nan
# 6                  nan
# 7                  nan
# 8                  nan
# 9                  nan
# 10                 nan
# 11                 nan
# 12                 nan
# 13                 nan
# 14                 nan
# 15                 nan
# 16                 nan
# 17                 nan
# 18                 nan
# 19                 nan
# 20                 nan
# 21                 nan
# 22                 nan
# 23                 nan
# 24                 nan
# 25                 nan
# 26                 nan
# 27                 nan
# 28                 nan
# 29                 nan
# 30    63,334,430,000.0
# 31                 nan
# 32                 nan
# 33                 nan
# 34                 nan
# 35 2,026,053,737,000.0
# 36                 nan
# 37 1,363,011,970,000.0
# 38                 nan
# 39                 nan
# 40                 nan
# 41   530,669,808,000.0
# 42                 nan
# 43                 nan
# 44                 nan
#
# [45 rows x 64 columns]

# %%
for num in range(0,5):
    print(num)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#     def extract_fs(self,
#                    bgn_de: str,
#                    end_de: str = None,
#                    fs_tp: Tuple[str] = ('bs', 'is', 'cis', 'cf'),
#                    separate: bool = False,
#                    report_tp: str = 'annual',
#                    lang: str = 'ko',
#                    separator: bool = True) -> FinancialStatement:
"""
 재무제표 검색
 Parameters
 ----------
 bgn_de: str
     검색 시작일자(YYYYMMDD)
 end_de: str, optional
     검색 종료일자(YYYYMMDD)
 fs_tp: tuple of str, optional
     'bs' 재무상태표, 'is' 손익계산서, 'cis' 포괄손익계산서, 'cf' 현금흐름표
 separate: bool, optional
     개별재무제표 여부
 report_tp: str, optional
     'annual' 1년, 'half' 반기, 'quarter' 분기
 lang: str, optional
     'ko' 한글, 'en' 영문
 separator: bool, optional
     1000단위 구분자 표시 여부
 Returns
 -------
 FinancialStatement
     제무제표 검색 결과
"""
# Out:
# "\n 재무제표 검색\n Parameters\n ----------\n bgn_de: str\n     검색 시작일자(YYYYMMDD)\n end_de: str, optional\n     검색 종료일자(YYYYMMDD)\n fs_tp: tuple of str, optional\n     'bs' 재무상태표, 'is' 손익계산서, 'cis' 포괄손익계산서, 'cf' 현금흐름표\n separate: bool, optional\n     개별재무제표 여부\n report_tp: str, optional\n     'annual' 1년, 'half' 반기, 'quarter' 분기\n lang: str, optional\n     'ko' 한글, 'en' 영문\n separator: bool, optional\n     1000단위 구분자 표시 여부\n Returns\n -------\n FinancialStatement\n     제무제표 검색 결과\n     "

# %%
type(fs[1])
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_excel('./fsdata/00126380_annual.xlsx', index_col=0, header=2)

# %%
df.columns = ['concept_id','label_ko','label_en','class0','class1','class2','class3','class4','연결재무제표','연결재무제표','연결재무제표', '연결재무제표']

# %%
df.drop(['concept_id'], axis=1, inplace=True)

# %%
for i in df['class0']:
    i = i.replace('*[abstract]', '')

# %%
samsung.info['sector']
# Out:
# '통신 및 방송 장비 제조업'

# %%
lgCa = corp_list.find_by_corp_name('LG화학', exactly=True)[0]

# %%
lgCa.info
# Out:
# {'corp_code': '00356361',
#  'corp_name': 'LG화학',
#  'stock_code': '051910',
#  'modify_date': '20200512',
#  'sector': '기초 화학물질 제조업',
#  'product': '유화/기능/합성수지,재생섬유소,산업재,리튬이온전지,평광판,PVC 제조,도매',
#  'corp_cls': 'Y'}

# %%
trash = corp_list.find_by_corp_name('신풍제약', exactly=True)[0]

# %%
fs.save()
# Out:
# {'bgn_de': '20180101',
#  'corp_code': '00126380',
#  'end_de': None,
#  'financial statement': [{'title': '[D210000] Statement of financial position, '
#                                    'current/non-current - Consolidated '
#                                    'financial statements (Unit: KRW)'},
#                          {'title': '[D310000] Income statement, by function of '
#                                    'expense - Consolidated financial '
#                                    'statements (Unit: KRW)'},
#                          {'title': '[D410000] Statement of comprehensive '
#                                    'income - Consolidated financial statements '
#                                    '(Unit: KRW)'},
#                          {'title': '[D520000] Statement of cash flows, '
#                                    'indirect method - Consolidated financial '
#                                    'statements (Unit: KRW)'}],
#  'lang': 'ko',
#  'report_tp': 'quarter',
#  'separate': False,
#  'separator': True}

# %%
fs.info.keys()
# Out:
# dict_keys(['corp_code', 'bgn_de', 'end_de', 'separate', 'report_tp', 'lang', 'separator', 'financial statement'])

# %%
df = pd.read_excel('../kospi top 50.xlsx')

# %%
corps = df['corp']
corps
# Out:
# 0         신한지주
# 1         KB금융
# 2         삼성생명
# 3           LG
# 4       하나금융지주
# 5         삼성화재
# 6       우리금융지주
# 7         기업은행
# 8       미래에셋대우
# 9           SK
# 10       NAVER
# 11     삼성에스디에스
# 12       엔씨소프트
# 13         코웨이
# 14      현대글로비스
# 15         카카오
# 16         넷마블
# 17        삼성물산
# 18      한국조선해양
# 19        현대건설
# 20         삼성전자
# 21       sk하이닉스
# 22    삼성바이오로직스
# 23       현대자동차
# 24        LG화학
# 25       현대모비스
# 26      lg생활건강
# 27         포스코
# 28         기아차
# 29       삼성SDI
# 30     SK이노베이션
# 31        LG전자
# 32      아모레퍼시픽
# 33        삼성전기
# 34       S-Oil
# 35        고려아연
# 36       롯데케미칼
# 37     LG디스플레이
# 38       한온시스템
# 39    아모레퍼시픽그룹
# 40     현대중공업지주
# 41        셀트리온
# 42       SK텔레콤
# 43      LG유플러스
# 44          KT
# Name: corp, dtype: object

# %%
for co in corps:
    print(co)
    co = co.strip()
#     corp_list = dart.corp.CorpList()
    try:
        corp = corp_list.find_by_corp_name(co, exactly=True)[0]    
    except:
        corp = corp_list.find_by_corp_name(co, exactly=True)[1]    
    try:
        fs = corp.extract_fs(bgn_de='19870101', report_tp='quarter') # fs_tp = bs, is, cis, cf

        # 0, 1, 3
        bs = fs[0]
        Is = fs[1]
        cf = fs[3]

        bs.to_csv('./fsdata/bs{}.csv'.format(co))
        Is.to_csv('./fsdata/Is{}.csv'.format(co))
        cf.to_csv('./fsdata/cf{}.csv'.format(co))
    except:
        print('pass')
# Out:
# 신한지주
# HBox(children=(FloatProgress(value=0.0, description='Annual reports', max=18.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Semiannual reports', max=18.0, style=ProgressStyle(descri…
# HBox(children=(FloatProgress(value=0.0, description='Quarterly report', max=38.0, style=ProgressStyle(descript…
# KB금융
# HBox(children=(FloatProgress(value=0.0, description='Annual reports', max=11.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Semiannual reports', max=11.0, style=ProgressStyle(descri…
# HBox(children=(FloatProgress(value=0.0, description='Quarterly report', max=24.0, style=ProgressStyle(descript…
# 삼성생명
# HBox(children=(FloatProgress(value=0.0, description='Annual reports', max=19.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Semiannual reports', max=19.0, style=ProgressStyle(descri…
# C:\Users\sundooedu\AppData\Roaming\Python\Python37\site-packages\dart_fss\fs\extract.py:204: RuntimeWarning: Date data length does not match table header.So last date was set using last data(19000101).
#   warnings.warn(warnings_text, RuntimeWarning)
# HBox(children=(FloatProgress(value=0.0, description='Quarterly report', max=38.0, style=ProgressStyle(descript…
# LG
# Output()
# Output()
# HBox(children=(FloatProgress(value=0.0, description='Annual reports', max=21.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Semiannual reports', max=21.0, style=ProgressStyle(descri…
# HBox(children=(FloatProgress(value=0.0, description='Quarterly report', max=41.0, style=ProgressStyle(descript…
# 하나금융지주
# HBox(children=(FloatProgress(value=0.0, description='Annual reports', max=14.0, style=ProgressStyle(descriptio…
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\dart_fss\fs\extract.py in merge_fs(fs_df, label_df, report, fs_tp, lang, separate)
#     796         # 보고서의 웹페이지에서 재무제표 추출
# --> 797         nfs_df = analyze_html(report=report, fs_tp=fs_tp, lang=lang, separate=separate)
#     798
#
# ~\AppData\Roaming\Python\Python37\site-packages\dart_fss\fs\extract.py in analyze_html(report, fs_tp, lang, separate)
#     531
# --> 532     extract_results = extract_fs_table(fs_table=fs_table, fs_tp=fs_tp, separate=separate, lang=lang)
#     533     return extract_results
#
# ~\AppData\Roaming\Python\Python37\site-packages\dart_fss\fs\extract.py in extract_fs_table(fs_table, fs_tp, separate, lang)
#     438             if table['table']:
# --> 439                 columns = convert_thead_into_columns(fs_tp=tp, fs_table=table, separate=separate, lang=lang)
#     440                 df = convert_tbody_to_dataframe(columns=columns, fs_table=table)
#
# ~\AppData\Roaming\Python\Python37\site-packages\dart_fss\fs\extract.py in convert_thead_into_columns(fs_tp, fs_table, separate, lang)
#     143     th_colspan_list = [int(th.attrs.get('colspan', 1)) for th in thead.tr.find_all('th')]
# --> 144     date_info = extract_date_from_header(fs_table['header'])
#     145     # Regular Expression for title
#
# ~\AppData\Roaming\Python\Python37\site-packages\dart_fss\fs\extract.py in extract_date_from_header(header)
#     104                     day = int(d[2])
# --> 105                     date.append(datetime(year, month, day))
#     106                 if len(date) > 0:
#
# ValueError: day is out of range for month
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-37-087d78faf7ca> in <module>
#       8         corp = corp_list.find_by_corp_name(co, exactly=True)[1]
#       9
# ---> 10     fs = corp.extract_fs(bgn_de='19870101', report_tp='quarter') # fs_tp = bs, is, cis, cf
#      11
#      12     # 0, 1, 3
#
# ~\AppData\Roaming\Python\Python37\site-packages\dart_fss\corp\corp.py in extract_fs(self, bgn_de, end_de, fs_tp, separate, report_tp, lang, separator)
#     225
#     226          """
# --> 227         return extract(self.corp_code, bgn_de, end_de, fs_tp, separate, report_tp, lang, separator)
#
# ~\AppData\Roaming\Python\Python37\site-packages\dart_fss\fs\extract.py in extract(corp_code, bgn_de, end_de, fs_tp, separate, report_tp, lang, separator)
#    1078
#    1079         for report in tqdm(reports[next_index:], desc='Annual reports', unit='report'):
# -> 1080             statements, label_df = merge_fs(statements, label_df, report, fs_tp=fs_tp, separate=separate, lang=lang)
#    1081
#    1082         if str_compare(report_tp, 'half') or str_compare(report_tp, 'quarter'):
#
# ~\AppData\Roaming\Python\Python37\site-packages\dart_fss\fs\extract.py in merge_fs(fs_df, label_df, report, fs_tp, lang, separate)
#     848     except Exception:
#     849         msg = 'An error occurred while fetching or analyzing {}.'.format(report.to_dict())
# --> 850         raise RuntimeError(msg)
#     851
#     852
#
# RuntimeError: An error occurred while fetching or analyzing {'rcp_no': '20120330001745', 'corp_code': '00547583', 'corp_name': '하나금융지주', 'stock_code': '086790', 'corp_cls': 'Y', 'report_nm': '사업보고서 (2011.12)', 'flr_nm': '하나금융지주', 'rcept_dt': '20120330', 'rm': '연'}.

# %%
corp_list
# Out:
# Number of companies: 81312

# %%
corp = corp_list.find_by_corp_name('LG유플러스', exactly=True)[0]

# %%
corp
# Out:
# [00231363]LG유플러스
