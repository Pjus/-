# %%
import pandas as pd

df = pd.read_csv('./fsdata/Is삼성생명.csv', index_col = 0)

# %%
df
# Out:
#       Income statement(Unit: KRW) 20100401-20110331 20090401-20100331  \
# NaN                      label_ko       ('연결재무제표',)       ('연결재무제표',)
# 0.0                        Ⅰ.영업수익  26230238000000.0  25761194000000.0
# 1.0                 1.보험료수익(주석21)  14607546000000.0  14523218000000.0
# 2.0                       가.개인보험료  14138120000000.0  14032980000000.0
# 3.0                       나.단체보험료    469426000000.0    490238000000.0
# ...                           ...               ...               ...
# 97.0                  1.지배회사지분순이익   1924853000000.0    906095000000.0
# 98.0                  2.소수주주지분순이익     -3523000000.0      -374000000.0
# 99.0       Ⅸ.지배회사지분순이익의주당이익(주석28)               NaN               NaN
# 100.0             1.기본주당순이익(단위:원)            9624.0            4530.0
# 101.0             2.희석주당순이익(단위:원)            9624.0            4530.0
#
#       20080401-20090331 20070401-20080331 20060401-20070331 20050401-20060331  \
# ...
