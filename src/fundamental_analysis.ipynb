# %%
import FundamentalAnalysis as fa
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np


ticker = "AAPL"
api_key = "d2b83a9cbe59bd13f8c7615015e41b0e"

# %%
# Show the available companies
companies = fa.available_companies(api_key)

# %%
companies
# Out:
#                                             name     price  \
# symbol
# SPY                                 SPDR S&P 500  323.9600
# CMCSA   Comcast Corporation Class A Common Stock   43.6700
# KMI                           Kinder Morgan Inc.   14.3200
# INTC                           Intel Corporation   47.9900
# MU                        Micron Technology Inc.   50.7400
# ...                                          ...       ...
# PSACU                                      PSACU    9.9799
# SRGA                                        SRGA    3.0200
# VWID                                        VWID   25.8045
# FJUL                                        FJUL   30.3916
# DJUL                                        DJUL   30.3900
#
#                        exchange
# symbol
# SPY                   NYSE Arca
# CMCSA      Nasdaq Global Select
# KMI     New York Stock Exchange
# INTC       Nasdaq Global Select
# MU         Nasdaq Global Select
# ...                         ...
# ...

# %%
companies
# Out:
#                                             name     price  \
# symbol
# SPY                                 SPDR S&P 500  323.9600
# CMCSA   Comcast Corporation Class A Common Stock   43.6700
# KMI                           Kinder Morgan Inc.   14.3200
# INTC                           Intel Corporation   47.9900
# MU                        Micron Technology Inc.   50.7400
# ...                                          ...       ...
# PSACU                                      PSACU    9.9799
# SRGA                                        SRGA    3.0200
# VWID                                        VWID   25.8045
# FJUL                                        FJUL   30.3916
# DJUL                                        DJUL   30.3900
#
#                        exchange
# symbol
# SPY                   NYSE Arca
# CMCSA      Nasdaq Global Select
# KMI     New York Stock Exchange
# INTC       Nasdaq Global Select
# MU         Nasdaq Global Select
# ...                         ...
# ...

# %%
# Collect general company information
profile = fa.profile('SDGR', api_key)

# %%
profile
# Out:
#                                                                    0
# symbol                                                          SDGR
# price                                                          75.87
# beta                                                               0
# volAvg                                                        955977
# mktCap                                                    4802297900
# lastDiv                                                            0
# range                                                      25.5-99.5
# changes                                                        -1.34
# companyName                                        Schrodinger, Inc.
# exchange                                                    NasdaqGS
# exchangeShortName                                             NASDAQ
# industry                                 Health Information Services
# website                                   http://www.schrodinger.com
# ...

# %%
# Collect recent company quotes
quotes = fa.quote(ticker, api_key)

# %%
quotes
# Out:
#                                                  0
# symbol                                        AAPL
# name                                    Apple Inc.
# price                                       384.76
# changesPercentage                             1.21
# change                                         4.6
# dayLow                                      375.07
# dayHigh                                     385.19
# yearHigh                                    399.82
# yearLow                                     192.58
# marketCap                              1.66768e+12
# priceAvg50                                 368.748
# priceAvg200                                313.381
# volume                                    30622619
# avgVolume                                 34597506
# exchange                                    NASDAQ
# open                                        376.75
# previousClose                               380.16
# ...

# %%
# Collect market cap and enterprise value
entreprise_value = fa.enterprise(ticker, api_key)
entreprise_value
# Out:
#                                       2019           2018          2017  \
# symbol                                AAPL           AAPL          AAPL
# stockPrice                          249.05         212.24        166.72
# numberOfShares                  4617834000     4955377000    5217242000
# marketCapitalization         1150071557700  1051729214480  869818586240
# minusCashAndCashEquivalents    48844000000    25913000000   20289000000
# addTotalDebt                  102067000000   102519000000   12992000000
# enterpriseValue              1203294557700  1128335214480  862521586240
#
#                                      2016          2015          2014  \
# symbol                               AAPL          AAPL          AAPL
# stockPrice                         117.65        115.28        105.11
# numberOfShares                 5470820000    5753421000    6085572000
# marketCapitalization         643641973000  663254372880  639654472920
# ...

# %%
# Show recommendations of Analysts
ratings = fa.rating('O', api_key)
ratings
# Out:
#     score recommendation
# P/B     5     Strong Buy
# ROA     5     Strong Buy
# DCF     5     Strong Buy
# P/E     5     Strong Buy
# ROE     3        Neutral
# D/E     5     Strong Buy

# %%
# Obtain DCFs over time Discountes cash flow
dcf_annually = fa.discounted_cash_flow(ticker, api_key, period="annual")
dcf_quarterly = fa.discounted_cash_flow(ticker, api_key, period="quarter")

# %%
dcf_quarterly
# Out:
#                 2020-07     2020-03     2019-12     2019-09     2019-06  \
# date         2020-07-30  2020-03-28  2019-12-28  2019-09-28  2019-06-29
# Stock Price      380.16      283.17      308.95      249.05      209.68
# DCF             390.667     292.326     317.958     259.627     220.523
#
#                 2019-03     2018-12     2018-09     2018-06     2018-03  ...  \
# date         2019-03-30  2018-12-29  2018-09-29  2018-06-30  2018-03-31  ...
# Stock Price      204.61       156.3      212.24      189.91      165.26  ...
# DCF             212.684     165.754     217.469     196.296     174.149  ...
#
#                 2011-09     2011-06     2011-03     2010-12     2010-09  \
# date         2011-09-24  2011-06-25  2011-03-26  2010-12-25  2010-09-25
# Stock Price       57.97       56.93       50.43       48.21       44.12
# DCF             68.5893     70.0309     67.7739     59.8864     56.5021
#
#                 2010-06     2010-03     2009-12     2009-09     2009-06
# ...

# %%
# Download detailed stock data
stock_data_detailed = fa.stock_data_detailed(ticker, api_key, begin="2001-01-01", end="2020-07-30")

# %%
stock_data_detailed = stock_data_detailed[::-1]
stock_data_detailed
# Out:
#               open    high     low   close adjClose       volume  \
# 2020-07-30  376.75  385.19  375.07  384.76   384.76  3.95325e+07
# 2020-07-29     375  380.92  374.85  380.16   380.16  2.25004e+07
# 2020-07-28  377.47   378.2  372.99  373.01   373.01  2.59064e+07
# 2020-07-27  374.84  379.62  373.92  379.24   379.24  3.03035e+07
# 2020-07-24  363.95  371.88  356.58  370.46   370.46  4.63597e+07
# ...            ...     ...     ...     ...      ...          ...
# 2001-01-08    1.21    1.21    1.14    1.18     1.02  9.34248e+07
# 2001-01-05    1.21    1.24    1.15    1.17     1.01  1.03089e+08
# 2001-01-04     1.3    1.32     1.2    1.22     1.06  1.84849e+08
# 2001-01-03    1.04    1.19    1.03    1.17     1.01  2.04268e+08
# 2001-01-02    1.06    1.09    1.04    1.06     0.92  1.13078e+08
#
#            unadjustedVolume   change changePercent     vwap           label  \
# 2020-07-30      3.95325e+07  8.01001         2.126  381.673     July 30, 20
# ...

# %%
growth_quarterly = fa.financial_statement_growth(ticker, api_key, period="quarter")
growth_quarterly
# Out:
#                                          2020-03   2019-12   2019-09  \
# revenueGrowth                          -0.364914  0.433776  0.190135
# grossProfitGrowth                      -0.364795  0.448484  0.202007
# ebitgrowth                             -0.497321  0.636416  0.353517
# operatingIncomeGrowth                  -0.497321  0.636416  0.353517
# netIncomeGrowth                        -0.494109  0.624726  0.362605
# epsgrowth                              -0.486111  0.652459  0.373874
# epsdilutedGrowth                       -0.484970  0.646865  0.377273
# weightedAverageSharesGrowth            -0.006222 -0.043915 -0.009086
# weightedAverageSharesDilutedGrowth     -0.005602 -0.041797 -0.009132
# dividendsperShareGrowth                -0.040370  0.063971 -0.032544
# operatingCashFlowGrowth                -0.563803  0.532697  0.711069
# freeCashFlowGrowth                     -0.596677  0.658145  0.778020
# tenYRevenueGrowthPerShare              -0.587583  0.200822  0.254744
# ...

# %%
from urllib.request import urlopen
period = 'quarter'

response = urlopen("https://financialmodelingprep.com/api/v3/discounted-cash-flow/" +
                       AAPL?period= + period + "&apikey=" + api_key)

# %%
response

# %%
growth_quarterly.T
# Out:
#          revenueGrowth  grossProfitGrowth  ebitgrowth  operatingIncomeGrowth  \
# 2020-03      -0.364914          -0.364795   -0.497321              -0.497321
# 2019-12       0.433776           0.448484    0.636416               0.636416
# 2019-09       0.190135           0.202007    0.353517               0.353517
# 2019-06      -0.072498          -0.073049   -0.139471              -0.139471
# 2019-03      -0.311885          -0.318754   -0.425383              -0.425383
# ...                ...                ...         ...                    ...
# 2002-03      -0.912727          -1.030806   -1.471698              -1.471698
# 2001-12      -0.646348          -0.473159   -1.141333              -1.141333
# 2001-09      87.363636          19.538462  -10.615385             -10.615385
# 2001-06       0.000000           0.000000    0.000000               0.000000
# 2001-03       0.000000           0.000000    0.000000               0.000000
#
# ...

# %%
# Show Key Metrics
key_metrics_quarterly = fa.key_metrics(ticker, api_key, period="quarter")

# Show a large set of in-depth ratios
financial_ratios_quarterly = fa.financial_ratios(ticker, api_key, period="quarter")

# Show the growth of the company
growth_quarterly = fa.financial_statement_growth(ticker, api_key, period="quarter")

# Download general stock data

# Download detailed stock data
stock_data_detailed = fa.stock_data_detailed(ticker, api_key, begin="2000-01-01", end="2020-01-01")


# Collect the Balance Sheet statements
balance_sheet_quarterly = fa.balance_sheet_statement(ticker, api_key, period="quarter")

# Collect the Income Statements
income_statement_quarterly = fa.income_statement(ticker, api_key, period="quarter")

# Collect the Cash Flow Statements
cash_flow_statement_quarterly = fa.cash_flow_statement(ticker, api_key, period="quarter")

# %%
key_metrics_quarterly_t = key_metrics_quarterly.T[::-1]
financial_ratios_quarterly_t = financial_ratios_quarterly.T[::-1]
growth_quarterly_t = growth_quarterly.T[::-1]['2001-06':]

# %%
income_statement_quarterly_t = income_statement_quarterly.T[::-1]
income_statement_quarterly_t_drop = income_statement_quarterly_t.drop(['acceptedDate', 'link', 'finalLink', 'period', 'fillingDate'], axis=1)

balance_sheet_quarterly_t = balance_sheet_quarterly.T[::-1]['2001-06':] #정리 필요
balance_sheet_quarterly_t_drop = balance_sheet_quarterly_t.drop(['acceptedDate', 'link', 'finalLink', 'period', 'fillingDate'], axis=1)

cash_flow_statement_quarterly_t = cash_flow_statement_quarterly.T[::-1] #정리 필요
cash_flow_statement_quarterly_t_drop = cash_flow_statement_quarterly_t.drop(['acceptedDate', 'link', 'finalLink', 'period', 'fillingDate'], axis=1)

# %%
pre_scaled = pd.concat([income_statement_quarterly_t_drop, balance_sheet_quarterly_t_drop, cash_flow_statement_quarterly_t_drop], axis=1)

# %%
etc_al = pd.concat([key_metrics_quarterly_t, financial_ratios_quarterly_t, growth_quarterly_t], axis=1)

# %%
pre_scaled = pre_scaled.astype('float')

# %%
pre_scaled
# Out:
#               revenue  costOfRevenue   grossProfit  grossProfitRatio  \
# 2001-06  4.400000e+07   5.000000e+06  3.900000e+07          0.886364
# 2001-09  3.888000e+09   3.087000e+09  8.010000e+08          0.206019
# 2001-12  1.375000e+09   9.530000e+08  4.220000e+08          0.306909
# 2002-03  1.200000e+08   1.330000e+08 -1.300000e+07         -0.108333
# 2002-06  1.429000e+09   1.038000e+09  3.910000e+08          0.273618
# ...               ...            ...           ...               ...
# 2019-03  5.801500e+10   3.619400e+10  2.182100e+10          0.376127
# 2019-06  5.380900e+10   3.358200e+10  2.022700e+10          0.375904
# 2019-09  6.404000e+10   3.972700e+10  2.431300e+10          0.379653
# 2019-12  9.181900e+10   5.660200e+10  3.521700e+10          0.383548
# 2020-03  5.831300e+10   3.594300e+10  2.237000e+10          0.383619
#
#          researchAndDevelopmentExpenses  generalAndAdministrativeExpenses  \
# ...

# %%
np.log(pre_scaled)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.
#            revenue  costOfRevenue  grossProfit  grossProfitRatio  \
# 2001-06  17.599700      15.424948    17.479072         -0.120628
# 2001-09  22.081161      21.850466    20.501372         -1.579789
# 2001-12  21.041720      20.675125    19.860516         -1.181204
# 2002-03  18.603002      18.705860          NaN               NaN
# 2002-06  21.080241      20.760562    19.784218         -1.296023
# ...            ...            ...          ...               ...
# 2019-03  24.783967      24.312159    23.806139         -0.977829
# 2019-06  24.708707      24.237256    23.730284         -0.978422
# ...

# %%
df_al = pd.concat([scaled_income, key_metrics_quarterly_t, financial_ratios_quarterly_t, growth_quarterly_t], axis=1)

# %%
scaler = MinMaxScaler()

# %%
scaled_income = pd.DataFrame(scaled_income_statement_quarterly_t_drop, columns=income_statement_quarterly_t_drop.columns, index=income_statement_quarterly_t_drop.index)

# %%
for i in income_statement_quarterly_t['fillingDate'].values:
    print(i)
    print(stock_data_detailed.loc[i]['close'])
