# %%
import dart_fss as dart

import pandas as pd

# %%
api_key='35d444d5a2ca8c271de34c8d296baf7474c37035' 
dart.set_api_key(api_key=api_key)
# Out:
# '35d444d5a2ca8c271de34c8d296baf7474c37035'

# %%
# DART 에 공시된 회사 리스트 불러오기
corp_list = dart.get_corp_list()
# Out:
# Output()
# Output()
# Output()

# %%
corp_list
# Out:
# Number of companies: 81312

# %%
# 삼성전자 검색
samsung = corp_list.find_by_corp_name('삼성전자', exactly=True)[0]

# %%
samsung
# Out:
# [00126380]삼성전자

# %%
# 2018년부터 연간 연결재무제표 불러오기
fs = samsung.extract_fs(bgn_de='20180101')
# Out:
# Output()
# Output()
# HBox(children=(FloatProgress(value=0.0, description='Annual reports', max=2.0, style=ProgressStyle(description…
# C:\Users\sundooedu\AppData\Roaming\Python\Python37\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
#     def extract_fs(self,
#                    bgn_de: str,
#                    end_de: str = None,
#                    fs_tp: Tuple[str] = ('bs', 'is', 'cis', 'cf'),
#                    separate: bool = False,
#                    report_tp: str = 'annual',
#                    lang: str = 'ko',
#                    separator: bool = True) -> FinancialStatement:
"""
 재무제표 검색
 Parameters
 ----------
 bgn_de: str
     검색 시작일자(YYYYMMDD)
 end_de: str, optional
     검색 종료일자(YYYYMMDD)
 fs_tp: tuple of str, optional
     'bs' 재무상태표, 'is' 손익계산서, 'cis' 포괄손익계산서, 'cf' 현금흐름표
 separate: bool, optional
     개별재무제표 여부
 report_tp: str, optional
     'annual' 1년, 'half' 반기, 'quarter' 분기
 lang: str, optional
     'ko' 한글, 'en' 영문
 separator: bool, optional
     1000단위 구분자 표시 여부
 Returns
 -------
 FinancialStatement
     제무제표 검색 결과
"""
# Out:
# "\n 재무제표 검색\n Parameters\n ----------\n bgn_de: str\n     검색 시작일자(YYYYMMDD)\n end_de: str, optional\n     검색 종료일자(YYYYMMDD)\n fs_tp: tuple of str, optional\n     'bs' 재무상태표, 'is' 손익계산서, 'cis' 포괄손익계산서, 'cf' 현금흐름표\n separate: bool, optional\n     개별재무제표 여부\n report_tp: str, optional\n     'annual' 1년, 'half' 반기, 'quarter' 분기\n lang: str, optional\n     'ko' 한글, 'en' 영문\n separator: bool, optional\n     1000단위 구분자 표시 여부\n Returns\n -------\n FinancialStatement\n     제무제표 검색 결과\n     "

# %%
fs.save()
# Out:
# 'C:\\Users\\sundooedu\\Desktop\\DART_Crawling\\src\\fsdata\\00126380_annual.xlsx'

# %%
fs
# Out:
# {'bgn_de': '20180101',
#  'corp_code': '00126380',
#  'end_de': None,
#  'financial statement': [{'title': '[D210000] Statement of financial position, '
#                                    'current/non-current - Consolidated '
#                                    'financial statements (Unit: KRW)'},
#                          {'title': '[D310000] Income statement, by function of '
#                                    'expense - Consolidated financial '
#                                    'statements (Unit: KRW)'},
#                          {'title': '[D410000] Statement of comprehensive '
#                                    'income - Consolidated financial statements '
#                                    '(Unit: KRW)'},
#                          {'title': '[D520000] Statement of cash flows, '
#                                    'indirect method - Consolidated financial '
#                                    'statements (Unit: KRW)'}],
#  'lang': 'ko',
#  'report_tp': 'annual',
#  'separate': False,
#  'separator': True}

# %%
df = pd.read_excel('./fsdata/00126380_annual.xlsx', index_col=0, header=2)

# %%
df.columns = ['concept_id','label_ko','label_en','class0','class1','class2','class3','class4','연결재무제표','연결재무제표','연결재무제표', '연결재무제표']

# %%
df.drop(['concept_id'], axis=1, inplace=True)

# %%
for i in df['class0']:
    i = i.replace('*[abstract]', '')

# %%
df
# Out:
#            label_ko                                           label_en  \
# 0              유동자산                                     Current assets
# 1          현금및현금성자산                          Cash and cash equivalents
# 2            단기금융상품                   Short-term financial instruments
# 3        단기매도가능금융자산                Available-for-sale financial assets
# 4       단기상각후원가금융자산                   after depreciation capital asset
# 5   단기당기손익-공정가치금융자산  Current financial assets at fair value through...
# 6              매출채권                        Short-term trade Receivable
# 7               미수금                          Other account receivables
# 8               선급금                                    Advance payment
# 9              선급비용                                    Prepaid expense
# 10             재고자산                                        Inventories
# 11           기타유동자산                               Other current assets
# 12            비유동자산                                 Non-current assets
# 13       장기매도가능금융자산                  Long-term deposits not classified
# 14         만기보유금융자산                                   Held-to-maturity
# 15        상각후원가금융자산                   after depreciation capital asset
# 16  기타포괄손익-공정가치금융자산                       oci-fair value capital asset
# 17    당기손익-공정가치금융자산                    income-fair value capital asset
# 18   관계기업 및 공동기업 투자  Availalble for sale financial asset associates...
# 19             유형자산                      Property, plant and equipment
# 20             무형자산                                  Intangible assets
# 21          순확정급여자산                   Deposits for severance insurance
# 22          이연법인세자산                                Deferred tax assets
# 23          기타비유동자산                           Other non-current assets
# 24             자산총계                                       Total assets
# 25             유동부채                                Current liabilities
# 26             매입채무                              Account payable Trade
# 27            단기차입금                              Short-term borrowings
# 28             미지급금                                       Other payble
# 29              선수금                                   Advance received
# 30              예수금                                       Withholdings
# 31            미지급비용                                    Accrued expense
# 32          당기법인세부채                            Current tax liabilities
# 33          유동성장기부채  Current portion of long-term borrowings and de...
# 34             충당부채                                 Current provisions
# 35           기타유동부채                          Other current liabilities
# 36            비유동부채                            Non-current liabilities
# 37               사채                                       Bonds issued
# 38            장기차입금                        Long-term borrowings, gross
# 39           장기미지급금                    Long-Term other Payables, gross
# 40          순확정급여부채                Post-employment benefit obligations
# 41          이연법인세부채                           Deferred tax liabilities
# 42           장기충당부채                             Non-current provisions
# 43          기타비유동부채                      Other non-current liabilities
# 44             부채총계                                  Total liabilities
# 45       지배기업 소유주지분            Equity attributable to owners of parent
# 46              자본금                                     Issued capital
# 47           우선주자본금                  Issued capital of preferred stock
# 48           보통주자본금                     Issued capital of common stock
# 49          주식발행초과금                                      Share premium
# 50       이익잉여금(결손금)                                  Retained earnings
# 51           기타자본항목             Elements of other stockholder's equity
# 52            비지배지분                          Non-controlling interests
# 53             자본총계                                       Total equity
# 54          자본과부채총계                       Total equity and liabilities
#
#               class0         class1      class2           class3  class4  \
# 0   재무상태표 [abstract]  자산 [abstract]        유동자산              NaN     NaN
# 1   재무상태표 [abstract]  자산 [abstract]        유동자산         현금및현금성자산     NaN
# 2   재무상태표 [abstract]  자산 [abstract]        유동자산           단기금융상품     NaN
# 3   재무상태표 [abstract]  자산 [abstract]        유동자산       단기매도가능금융자산     NaN
# 4   재무상태표 [abstract]  자산 [abstract]        유동자산      단기상각후원가금융자산     NaN
# 5   재무상태표 [abstract]  자산 [abstract]        유동자산  단기당기손익-공정가치금융자산     NaN
# 6   재무상태표 [abstract]  자산 [abstract]        유동자산             매출채권     NaN
# 7   재무상태표 [abstract]  자산 [abstract]        유동자산              미수금     NaN
# 8   재무상태표 [abstract]  자산 [abstract]        유동자산              선급금     NaN
# 9   재무상태표 [abstract]  자산 [abstract]        유동자산             선급비용     NaN
# 10  재무상태표 [abstract]  자산 [abstract]        유동자산             재고자산     NaN
# 11  재무상태표 [abstract]  자산 [abstract]        유동자산           기타유동자산     NaN
# 12  재무상태표 [abstract]  자산 [abstract]       비유동자산              NaN     NaN
# 13  재무상태표 [abstract]  자산 [abstract]       비유동자산       장기매도가능금융자산     NaN
# 14  재무상태표 [abstract]  자산 [abstract]       비유동자산         만기보유금융자산     NaN
# 15  재무상태표 [abstract]  자산 [abstract]       비유동자산        상각후원가금융자산     NaN
# 16  재무상태표 [abstract]  자산 [abstract]       비유동자산  기타포괄손익-공정가치금융자산     NaN
# 17  재무상태표 [abstract]  자산 [abstract]       비유동자산    당기손익-공정가치금융자산     NaN
# 18  재무상태표 [abstract]  자산 [abstract]       비유동자산   관계기업 및 공동기업 투자     NaN
# 19  재무상태표 [abstract]  자산 [abstract]       비유동자산             유형자산     NaN
# 20  재무상태표 [abstract]  자산 [abstract]       비유동자산             무형자산     NaN
# 21  재무상태표 [abstract]  자산 [abstract]       비유동자산          순확정급여자산     NaN
# 22  재무상태표 [abstract]  자산 [abstract]       비유동자산          이연법인세자산     NaN
# 23  재무상태표 [abstract]  자산 [abstract]       비유동자산          기타비유동자산     NaN
# 24  재무상태표 [abstract]  자산 [abstract]        자산총계              NaN     NaN
# 25  재무상태표 [abstract]  부채 [abstract]        유동부채              NaN     NaN
# 26  재무상태표 [abstract]  부채 [abstract]        유동부채             매입채무     NaN
# 27  재무상태표 [abstract]  부채 [abstract]        유동부채            단기차입금     NaN
# 28  재무상태표 [abstract]  부채 [abstract]        유동부채             미지급금     NaN
# 29  재무상태표 [abstract]  부채 [abstract]        유동부채              선수금     NaN
# 30  재무상태표 [abstract]  부채 [abstract]        유동부채              예수금     NaN
# 31  재무상태표 [abstract]  부채 [abstract]        유동부채            미지급비용     NaN
# 32  재무상태표 [abstract]  부채 [abstract]        유동부채          당기법인세부채     NaN
# 33  재무상태표 [abstract]  부채 [abstract]        유동부채          유동성장기부채     NaN
# 34  재무상태표 [abstract]  부채 [abstract]        유동부채             충당부채     NaN
# 35  재무상태표 [abstract]  부채 [abstract]        유동부채           기타유동부채     NaN
# 36  재무상태표 [abstract]  부채 [abstract]       비유동부채              NaN     NaN
# 37  재무상태표 [abstract]  부채 [abstract]       비유동부채               사채     NaN
# 38  재무상태표 [abstract]  부채 [abstract]       비유동부채            장기차입금     NaN
# 39  재무상태표 [abstract]  부채 [abstract]       비유동부채           장기미지급금     NaN
# 40  재무상태표 [abstract]  부채 [abstract]       비유동부채          순확정급여부채     NaN
# 41  재무상태표 [abstract]  부채 [abstract]       비유동부채          이연법인세부채     NaN
# 42  재무상태표 [abstract]  부채 [abstract]       비유동부채           장기충당부채     NaN
# 43  재무상태표 [abstract]  부채 [abstract]       비유동부채          기타비유동부채     NaN
# 44  재무상태표 [abstract]  부채 [abstract]        부채총계              NaN     NaN
# 45  재무상태표 [abstract]  자본 [abstract]  지배기업 소유주지분              NaN     NaN
# 46  재무상태표 [abstract]  자본 [abstract]  지배기업 소유주지분              자본금     NaN
# 47  재무상태표 [abstract]  자본 [abstract]  지배기업 소유주지분              자본금  우선주자본금
# 48  재무상태표 [abstract]  자본 [abstract]  지배기업 소유주지분              자본금  보통주자본금
# 49  재무상태표 [abstract]  자본 [abstract]  지배기업 소유주지분          주식발행초과금     NaN
# 50  재무상태표 [abstract]  자본 [abstract]  지배기업 소유주지분       이익잉여금(결손금)     NaN
# 51  재무상태표 [abstract]  자본 [abstract]  지배기업 소유주지분           기타자본항목     NaN
# 52  재무상태표 [abstract]  자본 [abstract]       비지배지분              NaN     NaN
# 53  재무상태표 [abstract]  자본 [abstract]        자본총계              NaN     NaN
# 54  재무상태표 [abstract]        자본과부채총계         NaN              NaN     NaN
#
#                   연결재무제표                연결재무제표                연결재무제표  \
# 0  181,385,260,000,000.0 174,697,424,000,000.0 146,982,464,000,000.0
# 1   26,885,999,000,000.0  30,340,505,000,000.0  30,545,130,000,000.0
# 2   76,252,052,000,000.0  65,893,797,000,000.0  49,447,696,000,000.0
# 3                    nan                   nan   3,191,375,000,000.0
# 4    3,914,216,000,000.0   2,703,693,000,000.0                   nan
# 5    1,727,436,000,000.0   2,001,948,000,000.0                   nan
# 6   35,131,343,000,000.0  33,867,733,000,000.0  27,695,995,000,000.0
# 7    4,179,120,000,000.0   3,080,733,000,000.0   4,108,961,000,000.0
# 8    1,426,833,000,000.0   1,361,807,000,000.0   1,753,673,000,000.0
# 9    2,406,220,000,000.0   4,136,167,000,000.0   3,835,219,000,000.0
# 10  26,766,464,000,000.0  28,984,704,000,000.0  24,983,355,000,000.0
# 11   2,695,577,000,000.0   2,326,337,000,000.0   1,421,060,000,000.0
# 12 171,179,237,000,000.0 164,659,820,000,000.0 154,769,626,000,000.0
# 13                   nan                   nan   7,752,180,000,000.0
# 14                   nan                   nan     106,751,000,000.0
# 15                   nan     238,309,000,000.0                   nan
# 16   8,920,712,000,000.0   7,301,351,000,000.0                   nan
# 17   1,049,004,000,000.0     775,427,000,000.0                   nan
# 18   7,591,612,000,000.0   7,313,206,000,000.0   6,802,351,000,000.0
# 19 119,825,474,000,000.0 115,416,724,000,000.0 111,665,648,000,000.0
# 20  20,703,504,000,000.0  14,891,598,000,000.0  14,760,483,000,000.0
# 21     589,832,000,000.0     562,356,000,000.0     825,892,000,000.0
# 22   4,505,049,000,000.0   5,468,002,000,000.0   5,061,687,000,000.0
# 23   7,994,050,000,000.0  12,692,847,000,000.0   7,794,634,000,000.0
# 24 352,564,497,000,000.0 339,357,244,000,000.0 301,752,090,000,000.0
# 25  63,782,764,000,000.0  69,081,510,000,000.0  67,175,114,000,000.0
# 26   8,718,222,000,000.0   8,479,916,000,000.0   9,083,907,000,000.0
# 27  14,393,468,000,000.0  13,586,660,000,000.0  15,767,619,000,000.0
# 28  12,002,513,000,000.0  10,711,536,000,000.0  13,899,633,000,000.0
# 29   1,072,062,000,000.0     820,265,000,000.0   1,249,174,000,000.0
# 30     897,355,000,000.0     951,254,000,000.0     793,582,000,000.0
# 31  19,359,624,000,000.0  20,339,687,000,000.0  13,996,273,000,000.0
# 32   1,387,773,000,000.0   8,720,050,000,000.0   7,408,348,000,000.0
# 33     846,090,000,000.0      33,386,000,000.0     278,619,000,000.0
# 34   4,068,627,000,000.0   4,384,038,000,000.0   4,294,820,000,000.0
# 35   1,037,030,000,000.0   1,054,718,000,000.0     403,139,000,000.0
# 36  25,901,312,000,000.0  22,522,557,000,000.0  20,085,548,000,000.0
# 37     975,298,000,000.0     961,972,000,000.0     953,361,000,000.0
# 38   2,197,181,000,000.0      85,085,000,000.0   1,814,446,000,000.0
# 39   2,184,249,000,000.0   3,194,043,000,000.0   2,043,729,000,000.0
# 40     470,780,000,000.0     504,064,000,000.0     389,922,000,000.0
# 41  17,053,808,000,000.0  15,162,523,000,000.0  11,710,781,000,000.0
# 42     611,100,000,000.0     663,619,000,000.0     464,324,000,000.0
# 43   2,408,896,000,000.0   1,951,251,000,000.0   2,708,985,000,000.0
# 44  89,684,076,000,000.0  91,604,067,000,000.0  87,260,662,000,000.0
# 45 254,915,472,000,000.0 240,068,993,000,000.0 207,213,416,000,000.0
# 46     897,514,000,000.0     897,514,000,000.0     897,514,000,000.0
# 47     119,467,000,000.0     119,467,000,000.0     119,467,000,000.0
# 48     778,047,000,000.0     778,047,000,000.0     778,047,000,000.0
# 49   4,403,893,000,000.0   4,403,893,000,000.0   4,403,893,000,000.0
# 50 254,582,894,000,000.0 242,698,956,000,000.0 215,811,200,000,000.0
# 51  -4,968,829,000,000.0  -7,931,370,000,000.0 -13,899,191,000,000.0
# 52   7,964,949,000,000.0   7,684,184,000,000.0   7,278,012,000,000.0
# 53 262,880,421,000,000.0 247,753,177,000,000.0 214,491,428,000,000.0
# 54 352,564,497,000,000.0 339,357,244,000,000.0 301,752,090,000,000.0
#
#                   연결재무제표
# 0  141,429,704,000,000.0
# 1   32,111,442,000,000.0
# 2   52,432,411,000,000.0
# 3    3,638,460,000,000.0
# 4                    nan
# 5                    nan
# 6   24,279,211,000,000.0
# 7    3,521,197,000,000.0
# 8    1,439,938,000,000.0
# 9    3,502,083,000,000.0
# 10  18,353,503,000,000.0
# 11   1,315,653,000,000.0
# 12 120,744,620,000,000.0
# 13   6,804,276,000,000.0
# 14                   nan
# 15                   nan
# 16                   nan
# 17                   nan
# 18   5,837,884,000,000.0
# 19  91,473,041,000,000.0
# 20   5,344,020,000,000.0
# 21     557,091,000,000.0
# 22   5,321,450,000,000.0
# 23   1,572,027,000,000.0
# 24 262,174,324,000,000.0
# 25  54,704,095,000,000.0
# 26   6,485,039,000,000.0
# 27  12,746,789,000,000.0
# 28  11,525,910,000,000.0
# 29   1,358,878,000,000.0
# 30     685,028,000,000.0
# 31  12,527,300,000,000.0
# 32   2,837,353,000,000.0
# 33   1,232,817,000,000.0
# 34   4,597,417,000,000.0
# 35     351,176,000,000.0
# 36  14,507,196,000,000.0
# 37      58,542,000,000.0
# 38   1,244,238,000,000.0
# 39   3,317,054,000,000.0
# 40     173,656,000,000.0
# 41   7,293,514,000,000.0
# 42     358,126,000,000.0
# 43   2,062,066,000,000.0
# 44  69,211,291,000,000.0
# 45 186,424,328,000,000.0
# 46     897,514,000,000.0
# 47     119,467,000,000.0
# 48     778,047,000,000.0
# 49   4,403,893,000,000.0
# 50 193,086,317,000,000.0
# 51 -11,934,586,000,000.0
# 52   6,538,705,000,000.0
# 53 192,963,033,000,000.0
# 54 262,174,324,000,000.0

# %%
samsung.info
# Out:
# {'corp_code': '00126380',
#  'corp_name': '삼성전자',
#  'stock_code': '005930',
#  'modify_date': '20191209',
#  'sector': '통신 및 방송 장비 제조업',
#  'product': 'IMT2000 서비스용 동기식 기지국,교환국장비,데이터단말기,동영상휴대폰,핵심칩,반도체제품,사무,계산 및 회계용기계',
#  'corp_cls': 'Y'}

# %%
lgCa = corp_list.find_by_corp_name('LG화학', exactly=True)[0]

# %%
lgCa.info
# Out:
# {'corp_code': '00356361',
#  'corp_name': 'LG화학',
#  'stock_code': '051910',
#  'modify_date': '20200512',
#  'sector': '기초 화학물질 제조업',
#  'product': '유화/기능/합성수지,재생섬유소,산업재,리튬이온전지,평광판,PVC 제조,도매',
#  'corp_cls': 'Y'}

# %%
trash = corp_list.find_by_corp_name('신풍제약', exactly=True)[0]

# %%
trash
# Out:
# [00137359]신풍제약

# %%
fs.info.keys()
# Out:
# dict_keys(['corp_code', 'bgn_de', 'end_de', 'separate', 'report_tp', 'lang', 'separator', 'financial statement'])

# %%
fs[0] #재무상태표
# Out:
#    [D210000] Statement of financial position, current/non-current - Consolidated financial statements (Unit: KRW)  \
#                                                                                                        concept_id
# 0                             ifrs-full_CurrentAssets
# 1                    ifrs-full_CashAndCashEquivalents
# 2   dart_ShortTermDepositsNotClassifiedAsCashEquiv...
# 3   entity00126380_udf_BS_2020210113420730_Current...
# 4   entity00126380_udf_BS_201851017339116_CurrentA...
# 5   ifrs-full_CurrentFinancialAssetsAtFairValueThr...
# 6                       dart_ShortTermTradeReceivable
# 7   entity00126380_udf_BS_201710182279121_CurrentA...
# 8   entity00126380_udf_BS_20171018221011173_Curren...
# 9   entity00126380_udf_BS_2017101822109437_Current...
# 10                              ifrs-full_Inventories
# 11                            dart_OtherCurrentAssets
# 12                         ifrs-full_NoncurrentAssets
# 13  entity00126380_udf_BS_2020210113513266_Noncurr...
# 14  entity00126380_udf_BS_2020210113515706_Noncurr...
# 15  entity00126380_udf_BS_20185101782898_Noncurren...
# 16  entity00126380_udf_BS_201851017830322_Noncurre...
# 17  entity00126380_udf_BS_201851017832579_Noncurre...
# 18  entity00126380_udf_BS_20171018221637438_Noncur...
# 19                ifrs-full_PropertyPlantAndEquipment
# 20        ifrs-full_IntangibleAssetsOtherThanGoodwill
# 21                 dart_DepositsForSeveranceInsurance
# 22                        ifrs-full_DeferredTaxAssets
# 23                         dart_OtherNonCurrentAssets
# 24                                   ifrs-full_Assets
# 25                       ifrs-full_CurrentLiabilities
# 26  entity00126380_udf_BS_20171018222617796_Curren...
# 27                      ifrs-full_ShorttermBorrowings
# 28  entity00126380_udf_BS_20171018222642264_Curren...
# 29  entity00126380_udf_BS_20171018222640707_Curren...
# 30  entity00126380_udf_BS_20171018222637261_Curren...
# 31  entity00126380_udf_BS_20171018222635206_Curren...
# 32                    ifrs-full_CurrentTaxLiabilities
# 33  entity00126380_udf_BS_20171024141934989_Curren...
# 34                        ifrs-full_CurrentProvisions
# 35                       dart_OtherCurrentLiabilities
# 36                    ifrs-full_NoncurrentLiabilities
# 37                                   dart_BondsIssued
# 38                       dart_LongTermBorrowingsGross
# 39                    dart_LongTermOtherPayablesGross
# 40              dart_PostemploymentBenefitObligations
# 41                   ifrs-full_DeferredTaxLiabilities
# 42                     ifrs-full_NoncurrentProvisions
# 43                    dart_OtherNonCurrentLiabilities
# 44                              ifrs-full_Liabilities
# 45       ifrs-full_EquityAttributableToOwnersOfParent
# 46                            ifrs-full_IssuedCapital
# 47                 dart_IssuedCapitalOfPreferredStock
# 48                    dart_IssuedCapitalOfCommonStock
# 49                             ifrs-full_SharePremium
# 50                         ifrs-full_RetainedEarnings
# 51             dart_ElementsOfOtherStockholdersEquity
# 52                  ifrs-full_NoncontrollingInterests
# 53                                   ifrs-full_Equity
# 54                     ifrs-full_EquityAndLiabilities
#
#                                                                         \
#            label_ko                                           label_en
# 0              유동자산                                     Current assets
# 1          현금및현금성자산                          Cash and cash equivalents
# 2            단기금융상품                   Short-term financial instruments
# 3        단기매도가능금융자산                Available-for-sale financial assets
# 4       단기상각후원가금융자산                   after depreciation capital asset
# 5   단기당기손익-공정가치금융자산  Current financial assets at fair value through...
# 6              매출채권                        Short-term trade Receivable
# 7               미수금                          Other account receivables
# 8               선급금                                    Advance payment
# 9              선급비용                                    Prepaid expense
# 10             재고자산                                        Inventories
# 11           기타유동자산                               Other current assets
# 12            비유동자산                                 Non-current assets
# 13       장기매도가능금융자산                  Long-term deposits not classified
# 14         만기보유금융자산                                   Held-to-maturity
# 15        상각후원가금융자산                   after depreciation capital asset
# 16  기타포괄손익-공정가치금융자산                       oci-fair value capital asset
# 17    당기손익-공정가치금융자산                    income-fair value capital asset
# 18   관계기업 및 공동기업 투자  Availalble for sale financial asset associates...
# 19             유형자산                      Property, plant and equipment
# 20             무형자산                                  Intangible assets
# 21          순확정급여자산                   Deposits for severance insurance
# 22          이연법인세자산                                Deferred tax assets
# 23          기타비유동자산                           Other non-current assets
# 24             자산총계                                       Total assets
# 25             유동부채                                Current liabilities
# 26             매입채무                              Account payable Trade
# 27            단기차입금                              Short-term borrowings
# 28             미지급금                                       Other payble
# 29              선수금                                   Advance received
# 30              예수금                                       Withholdings
# 31            미지급비용                                    Accrued expense
# 32          당기법인세부채                            Current tax liabilities
# 33          유동성장기부채  Current portion of long-term borrowings and de...
# 34             충당부채                                 Current provisions
# 35           기타유동부채                          Other current liabilities
# 36            비유동부채                            Non-current liabilities
# 37               사채                                       Bonds issued
# 38            장기차입금                        Long-term borrowings, gross
# 39           장기미지급금                    Long-Term other Payables, gross
# 40          순확정급여부채                Post-employment benefit obligations
# 41          이연법인세부채                           Deferred tax liabilities
# 42           장기충당부채                             Non-current provisions
# 43          기타비유동부채                      Other non-current liabilities
# 44             부채총계                                  Total liabilities
# 45       지배기업 소유주지분            Equity attributable to owners of parent
# 46              자본금                                     Issued capital
# 47           우선주자본금                  Issued capital of preferred stock
# 48           보통주자본금                     Issued capital of common stock
# 49          주식발행초과금                                      Share premium
# 50       이익잉여금(결손금)                                  Retained earnings
# 51           기타자본항목             Elements of other stockholder's equity
# 52            비지배지분                          Non-controlling interests
# 53             자본총계                                       Total equity
# 54          자본과부채총계                       Total equity and liabilities
#
#                                                                           \
#               class0         class1      class2           class3  class4
# 0   재무상태표 [abstract]  자산 [abstract]        유동자산             None    None
# 1   재무상태표 [abstract]  자산 [abstract]        유동자산         현금및현금성자산    None
# 2   재무상태표 [abstract]  자산 [abstract]        유동자산           단기금융상품    None
# 3   재무상태표 [abstract]  자산 [abstract]        유동자산       단기매도가능금융자산    None
# 4   재무상태표 [abstract]  자산 [abstract]        유동자산      단기상각후원가금융자산    None
# 5   재무상태표 [abstract]  자산 [abstract]        유동자산  단기당기손익-공정가치금융자산    None
# 6   재무상태표 [abstract]  자산 [abstract]        유동자산             매출채권    None
# 7   재무상태표 [abstract]  자산 [abstract]        유동자산              미수금    None
# 8   재무상태표 [abstract]  자산 [abstract]        유동자산              선급금    None
# 9   재무상태표 [abstract]  자산 [abstract]        유동자산             선급비용    None
# 10  재무상태표 [abstract]  자산 [abstract]        유동자산             재고자산    None
# 11  재무상태표 [abstract]  자산 [abstract]        유동자산           기타유동자산    None
# 12  재무상태표 [abstract]  자산 [abstract]       비유동자산             None    None
# 13  재무상태표 [abstract]  자산 [abstract]       비유동자산       장기매도가능금융자산    None
# 14  재무상태표 [abstract]  자산 [abstract]       비유동자산         만기보유금융자산    None
# 15  재무상태표 [abstract]  자산 [abstract]       비유동자산        상각후원가금융자산    None
# 16  재무상태표 [abstract]  자산 [abstract]       비유동자산  기타포괄손익-공정가치금융자산    None
# 17  재무상태표 [abstract]  자산 [abstract]       비유동자산    당기손익-공정가치금융자산    None
# 18  재무상태표 [abstract]  자산 [abstract]       비유동자산   관계기업 및 공동기업 투자    None
# 19  재무상태표 [abstract]  자산 [abstract]       비유동자산             유형자산    None
# 20  재무상태표 [abstract]  자산 [abstract]       비유동자산             무형자산    None
# 21  재무상태표 [abstract]  자산 [abstract]       비유동자산          순확정급여자산    None
# 22  재무상태표 [abstract]  자산 [abstract]       비유동자산          이연법인세자산    None
# 23  재무상태표 [abstract]  자산 [abstract]       비유동자산          기타비유동자산    None
# 24  재무상태표 [abstract]  자산 [abstract]        자산총계             None    None
# 25  재무상태표 [abstract]  부채 [abstract]        유동부채             None    None
# 26  재무상태표 [abstract]  부채 [abstract]        유동부채             매입채무    None
# 27  재무상태표 [abstract]  부채 [abstract]        유동부채            단기차입금    None
# 28  재무상태표 [abstract]  부채 [abstract]        유동부채             미지급금    None
# 29  재무상태표 [abstract]  부채 [abstract]        유동부채              선수금    None
# 30  재무상태표 [abstract]  부채 [abstract]        유동부채              예수금    None
# 31  재무상태표 [abstract]  부채 [abstract]        유동부채            미지급비용    None
# 32  재무상태표 [abstract]  부채 [abstract]        유동부채          당기법인세부채    None
# 33  재무상태표 [abstract]  부채 [abstract]        유동부채          유동성장기부채    None
# 34  재무상태표 [abstract]  부채 [abstract]        유동부채             충당부채    None
# 35  재무상태표 [abstract]  부채 [abstract]        유동부채           기타유동부채    None
# 36  재무상태표 [abstract]  부채 [abstract]       비유동부채             None    None
# 37  재무상태표 [abstract]  부채 [abstract]       비유동부채               사채    None
# 38  재무상태표 [abstract]  부채 [abstract]       비유동부채            장기차입금    None
# 39  재무상태표 [abstract]  부채 [abstract]       비유동부채           장기미지급금    None
# 40  재무상태표 [abstract]  부채 [abstract]       비유동부채          순확정급여부채    None
# 41  재무상태표 [abstract]  부채 [abstract]       비유동부채          이연법인세부채    None
# 42  재무상태표 [abstract]  부채 [abstract]       비유동부채           장기충당부채    None
# 43  재무상태표 [abstract]  부채 [abstract]       비유동부채          기타비유동부채    None
# 44  재무상태표 [abstract]  부채 [abstract]        부채총계             None    None
# 45  재무상태표 [abstract]  자본 [abstract]  지배기업 소유주지분             None    None
# 46  재무상태표 [abstract]  자본 [abstract]  지배기업 소유주지분              자본금    None
# 47  재무상태표 [abstract]  자본 [abstract]  지배기업 소유주지분              자본금  우선주자본금
# 48  재무상태표 [abstract]  자본 [abstract]  지배기업 소유주지분              자본금  보통주자본금
# 49  재무상태표 [abstract]  자본 [abstract]  지배기업 소유주지분          주식발행초과금    None
# 50  재무상태표 [abstract]  자본 [abstract]  지배기업 소유주지분       이익잉여금(결손금)    None
# 51  재무상태표 [abstract]  자본 [abstract]  지배기업 소유주지분           기타자본항목    None
# 52  재무상태표 [abstract]  자본 [abstract]       비지배지분             None    None
# 53  재무상태표 [abstract]  자본 [abstract]        자본총계             None    None
# 54  재무상태표 [abstract]        자본과부채총계        None             None    None
#
#                 20191231              20181231              20171231  \
#                (연결재무제표,)             (연결재무제표,)             (연결재무제표,)
# 0  181,385,260,000,000.0 174,697,424,000,000.0 146,982,464,000,000.0
# 1   26,885,999,000,000.0  30,340,505,000,000.0  30,545,130,000,000.0
# 2   76,252,052,000,000.0  65,893,797,000,000.0  49,447,696,000,000.0
# 3                    nan                   nan   3,191,375,000,000.0
# 4    3,914,216,000,000.0   2,703,693,000,000.0                   nan
# 5    1,727,436,000,000.0   2,001,948,000,000.0                   nan
# 6   35,131,343,000,000.0  33,867,733,000,000.0  27,695,995,000,000.0
# 7    4,179,120,000,000.0   3,080,733,000,000.0   4,108,961,000,000.0
# 8    1,426,833,000,000.0   1,361,807,000,000.0   1,753,673,000,000.0
# 9    2,406,220,000,000.0   4,136,167,000,000.0   3,835,219,000,000.0
# 10  26,766,464,000,000.0  28,984,704,000,000.0  24,983,355,000,000.0
# 11   2,695,577,000,000.0   2,326,337,000,000.0   1,421,060,000,000.0
# 12 171,179,237,000,000.0 164,659,820,000,000.0 154,769,626,000,000.0
# 13                   nan                   nan   7,752,180,000,000.0
# 14                   nan                   nan     106,751,000,000.0
# 15                   nan     238,309,000,000.0                   nan
# 16   8,920,712,000,000.0   7,301,351,000,000.0                   nan
# 17   1,049,004,000,000.0     775,427,000,000.0                   nan
# 18   7,591,612,000,000.0   7,313,206,000,000.0   6,802,351,000,000.0
# 19 119,825,474,000,000.0 115,416,724,000,000.0 111,665,648,000,000.0
# 20  20,703,504,000,000.0  14,891,598,000,000.0  14,760,483,000,000.0
# 21     589,832,000,000.0     562,356,000,000.0     825,892,000,000.0
# 22   4,505,049,000,000.0   5,468,002,000,000.0   5,061,687,000,000.0
# 23   7,994,050,000,000.0  12,692,847,000,000.0   7,794,634,000,000.0
# 24 352,564,497,000,000.0 339,357,244,000,000.0 301,752,090,000,000.0
# 25  63,782,764,000,000.0  69,081,510,000,000.0  67,175,114,000,000.0
# 26   8,718,222,000,000.0   8,479,916,000,000.0   9,083,907,000,000.0
# 27  14,393,468,000,000.0  13,586,660,000,000.0  15,767,619,000,000.0
# 28  12,002,513,000,000.0  10,711,536,000,000.0  13,899,633,000,000.0
# 29   1,072,062,000,000.0     820,265,000,000.0   1,249,174,000,000.0
# 30     897,355,000,000.0     951,254,000,000.0     793,582,000,000.0
# 31  19,359,624,000,000.0  20,339,687,000,000.0  13,996,273,000,000.0
# 32   1,387,773,000,000.0   8,720,050,000,000.0   7,408,348,000,000.0
# 33     846,090,000,000.0      33,386,000,000.0     278,619,000,000.0
# 34   4,068,627,000,000.0   4,384,038,000,000.0   4,294,820,000,000.0
# 35   1,037,030,000,000.0   1,054,718,000,000.0     403,139,000,000.0
# 36  25,901,312,000,000.0  22,522,557,000,000.0  20,085,548,000,000.0
# 37     975,298,000,000.0     961,972,000,000.0     953,361,000,000.0
# 38   2,197,181,000,000.0      85,085,000,000.0   1,814,446,000,000.0
# 39   2,184,249,000,000.0   3,194,043,000,000.0   2,043,729,000,000.0
# 40     470,780,000,000.0     504,064,000,000.0     389,922,000,000.0
# 41  17,053,808,000,000.0  15,162,523,000,000.0  11,710,781,000,000.0
# 42     611,100,000,000.0     663,619,000,000.0     464,324,000,000.0
# 43   2,408,896,000,000.0   1,951,251,000,000.0   2,708,985,000,000.0
# 44  89,684,076,000,000.0  91,604,067,000,000.0  87,260,662,000,000.0
# 45 254,915,472,000,000.0 240,068,993,000,000.0 207,213,416,000,000.0
# 46     897,514,000,000.0     897,514,000,000.0     897,514,000,000.0
# 47     119,467,000,000.0     119,467,000,000.0     119,467,000,000.0
# 48     778,047,000,000.0     778,047,000,000.0     778,047,000,000.0
# 49   4,403,893,000,000.0   4,403,893,000,000.0   4,403,893,000,000.0
# 50 254,582,894,000,000.0 242,698,956,000,000.0 215,811,200,000,000.0
# 51  -4,968,829,000,000.0  -7,931,370,000,000.0 -13,899,191,000,000.0
# 52   7,964,949,000,000.0   7,684,184,000,000.0   7,278,012,000,000.0
# 53 262,880,421,000,000.0 247,753,177,000,000.0 214,491,428,000,000.0
# 54 352,564,497,000,000.0 339,357,244,000,000.0 301,752,090,000,000.0
#
#                 20161231
#                (연결재무제표,)
# 0  141,429,704,000,000.0
# 1   32,111,442,000,000.0
# 2   52,432,411,000,000.0
# 3    3,638,460,000,000.0
# 4                   None
# 5                   None
# 6   24,279,211,000,000.0
# 7    3,521,197,000,000.0
# 8    1,439,938,000,000.0
# 9    3,502,083,000,000.0
# 10  18,353,503,000,000.0
# 11   1,315,653,000,000.0
# 12 120,744,620,000,000.0
# 13   6,804,276,000,000.0
# 14
# 15                  None
# 16                  None
# 17                  None
# 18   5,837,884,000,000.0
# 19  91,473,041,000,000.0
# 20   5,344,020,000,000.0
# 21     557,091,000,000.0
# 22   5,321,450,000,000.0
# 23   1,572,027,000,000.0
# 24 262,174,324,000,000.0
# 25  54,704,095,000,000.0
# 26   6,485,039,000,000.0
# 27  12,746,789,000,000.0
# 28  11,525,910,000,000.0
# 29   1,358,878,000,000.0
# 30     685,028,000,000.0
# 31  12,527,300,000,000.0
# 32   2,837,353,000,000.0
# 33   1,232,817,000,000.0
# 34   4,597,417,000,000.0
# 35     351,176,000,000.0
# 36  14,507,196,000,000.0
# 37      58,542,000,000.0
# 38   1,244,238,000,000.0
# 39   3,317,054,000,000.0
# 40     173,656,000,000.0
# 41   7,293,514,000,000.0
# 42     358,126,000,000.0
# 43   2,062,066,000,000.0
# 44  69,211,291,000,000.0
# 45 186,424,328,000,000.0
# 46     897,514,000,000.0
# 47     119,467,000,000.0
# 48     778,047,000,000.0
# 49   4,403,893,000,000.0
# 50 193,086,317,000,000.0
# 51 -11,934,586,000,000.0
# 52   6,538,705,000,000.0
# 53 192,963,033,000,000.0
# 54 262,174,324,000,000.0

# %%
fs[1] #손익계산서
# Out:
#    [D310000] Income statement, by function of expense - Consolidated financial statements (Unit: KRW)  \
#                                                                                            concept_id
# 0                                   ifrs-full_Revenue
# 1                               ifrs-full_CostOfSales
# 2                               ifrs-full_GrossProfit
# 3      dart_TotalSellingGeneralAdministrativeExpenses
# 4                            dart_OperatingIncomeLoss
# 5                                     dart_OtherGains
# 6                                    dart_OtherLosses
# 7   entity00126380_udf_IS_2017102191515184_IncomeS...
# 8                             ifrs-full_FinanceIncome
# 9   entity00126380_udf_IS_2017102191643789_IncomeS...
# 10                      ifrs-full_ProfitLossBeforeTax
# 11     ifrs-full_IncomeTaxExpenseContinuingOperations
# 12       ifrs-full_ProfitLossFromContinuingOperations
# 13                               ifrs-full_ProfitLoss
# 14   ifrs-full_ProfitLossAttributableToOwnersOfParent
# 15  ifrs-full_ProfitLossAttributableToNoncontrolli...
# 16                ifrs-full_BasicEarningsLossPerShare
# 17              ifrs-full_DilutedEarningsLossPerShare
#
#                                 \
#                       label_ko
# 0                      수익(매출액)
# 1                         매출원가
# 2                        매출총이익
# 3                      판매비와관리비
# 4                     영업이익(손실)
# 5                         기타수익
# 6                         기타비용
# 7                        지분법이익
# 8                         금융수익
# 9                         금융비용
# 10             법인세비용차감전순이익(손실)
# 11                       법인세비용
# 12                  계속영업이익(손실)
# 13                   당기순이익(손실)
# 14  지배기업의 소유주에게 귀속되는 당기순이익(손실)
# 15       비지배지분에 귀속되는 당기순이익(손실)
# 16                  기본주당이익(손실)
# 17                  희석주당이익(손실)
#
#                                                                          \
#                                              label_en            class0
# 0                                      Revenue(Sales)  손익계산서 [abstract]
# 1                                       Cost of sales  손익계산서 [abstract]
# 2                                        Gross profit  손익계산서 [abstract]
# 3             Selling general administrative expenses  손익계산서 [abstract]
# 4                              Operating income(loss)  손익계산서 [abstract]
# 5                                         Other gains  손익계산서 [abstract]
# 6                                        Other losses  손익계산서 [abstract]
# 7   Share of profit (loss) of associates and joint...  손익계산서 [abstract]
# 8                                      Finance income  손익계산서 [abstract]
# 9                                     Finance expense  손익계산서 [abstract]
# 10                           Profit (loss) before tax  손익계산서 [abstract]
# 11                                 Income tax expense  손익계산서 [abstract]
# 12           Profit (loss) from continuing operations  손익계산서 [abstract]
# 13                                      Profit (loss)  손익계산서 [abstract]
# 14    Profit (loss), attributable to owners of parent  손익계산서 [abstract]
# 15  Profit (loss), attributable to non-controlling...  손익계산서 [abstract]
# 16                    Basic earnings (loss) per share  손익계산서 [abstract]
# 17                  Diluted earnings (loss) per share  손익계산서 [abstract]
#
#                                                           \
#                       class1                      class2
# 0                    수익(매출액)                        None
# 1                       매출원가                        None
# 2                      매출총이익                        None
# 3                    판매비와관리비                        None
# 4                   영업이익(손실)                        None
# 5                       기타수익                        None
# 6                       기타비용                        None
# 7                      지분법이익                        None
# 8                       금융수익                        None
# 9                       금융비용                        None
# 10           법인세비용차감전순이익(손실)                        None
# 11                     법인세비용                        None
# 12                계속영업이익(손실)                        None
# 13                 당기순이익(손실)                        None
# 14  당기순이익(손실)의 귀속 [abstract]  지배기업의 소유주에게 귀속되는 당기순이익(손실)
# 15  당기순이익(손실)의 귀속 [abstract]       비지배지분에 귀속되는 당기순이익(손실)
# 16           주당이익 [abstract]                  기본주당이익(손실)
# 17           주당이익 [abstract]                  희석주당이익(손실)
#
#        20190101-20191231     20180101-20181231     20170101-20171231  \
#                (연결재무제표,)             (연결재무제표,)             (연결재무제표,)
# 0  230,400,881,000,000.0 243,771,415,000,000.0 239,575,376,000,000.0
# 1  147,239,549,000,000.0 132,394,411,000,000.0 129,290,661,000,000.0
# 2   83,161,332,000,000.0 111,377,004,000,000.0 110,284,715,000,000.0
# 3   55,392,823,000,000.0  52,490,335,000,000.0  56,639,677,000,000.0
# 4   27,768,509,000,000.0  58,886,669,000,000.0  53,645,038,000,000.0
# 5    1,778,666,000,000.0   1,485,037,000,000.0   3,010,657,000,000.0
# 6    1,414,707,000,000.0   1,142,018,000,000.0   1,419,648,000,000.0
# 7      412,960,000,000.0     539,845,000,000.0     201,442,000,000.0
# 8   10,161,632,000,000.0   9,999,321,000,000.0   9,737,391,000,000.0
# 9    8,274,871,000,000.0   8,608,896,000,000.0   8,978,913,000,000.0
# 10  30,432,189,000,000.0  61,159,958,000,000.0  56,195,967,000,000.0
# 11   8,693,324,000,000.0  16,815,101,000,000.0  14,009,220,000,000.0
# 12  21,738,865,000,000.0  44,344,857,000,000.0  42,186,747,000,000.0
# 13  21,738,865,000,000.0  44,344,857,000,000.0  42,186,747,000,000.0
# 14  21,505,054,000,000.0  43,890,877,000,000.0  41,344,569,000,000.0
# 15     233,811,000,000.0     453,980,000,000.0     842,178,000,000.0
# 16               3,166.0               6,461.0               5,997.0
# 17               3,166.0               6,461.0               5,997.0
#
#        20160101-20161231
#                (연결재무제표,)
# 0  201,866,745,000,000.0
# 1  120,277,715,000,000.0
# 2   81,589,030,000,000.0
# 3   52,348,358,000,000.0
# 4   29,240,672,000,000.0
# 5    3,238,261,000,000.0
# 6    2,463,814,000,000.0
# 7       19,501,000,000.0
# 8   11,385,645,000,000.0
# 9   10,706,613,000,000.0
# 10  30,713,652,000,000.0
# 11   7,987,560,000,000.0
# 12  22,726,092,000,000.0
# 13  22,726,092,000,000.0
# 14  22,415,655,000,000.0
# 15     310,437,000,000.0
# 16             157,967.0
# 17             157,967.0

# %%
fs[2]#포괄손익계산서
# Out:
#    [D410000] Statement of comprehensive income - Consolidated financial statements (Unit: KRW)  \
#                                                                                     concept_id
# 0                                ifrs-full_ProfitLoss
# 1                  ifrs-full_OtherComprehensiveIncome
# 2   dart_OtherComprehensiveIncomeThatWillNotBeRecl...
# 3   entity00126380_udf_IS_2018510181631532_OtherCo...
# 4   dart_ShareOfOtherComprehensiveIncomeOfAssociat...
# 5   dart_OtherComprehensiveIncomeNetOfTaxGainsLoss...
# 6   dart_OtherComprehensiveIncomeThatWillBeReclass...
# 7   entity00126380_udf_IS_2020210124628932_OtherCo...
# 8   dart_ShareOfOtherComprehensiveIncomeOfAssociat...
# 9   ifrs-full_GainsLossesOnExchangeDifferencesOnTr...
# 10      ifrs-full_GainsLossesOnCashFlowHedgesNetOfTax
# 11                      ifrs-full_ComprehensiveIncome
# 12  ifrs-full_ComprehensiveIncomeAttributableToOwn...
# 13  ifrs-full_ComprehensiveIncomeAttributableToNon...
#
#                                 \
#                       label_ko
# 0                    당기순이익(손실)
# 1                       기타포괄손익
# 2   후속적으로 당기손익으로 재분류되지 않는 포괄손익
# 3          기타포괄손익-공정가치금융자산평가손익
# 4   관계기업 및 공동기업의 기타포괄손익에 대한 지분
# 5                순확정급여부채 재측정요소
# 6      후속적으로 당기손익으로 재분류되는 포괄손익
# 7                 매도가능금융자산평가손익
# 8   관계기업 및 공동기업의 기타포괄손익에 대한 지분
# 9                  해외사업장환산외환차이
# 10            현금흐름위험회피파생상품평가손익
# 11                       총포괄손익
# 12                  지배기업 소유주지분
# 13                       비지배지분
#
#                                                                            \
#                                              label_en              class0
# 0                                       Profit (loss)  포괄손익계산서 [abstract]
# 1                          Other comprehensive income  포괄손익계산서 [abstract]
# 2   Other comprehensive income that will not be re...  포괄손익계산서 [abstract]
# 3                           oci-fair value assessment  포괄손익계산서 [abstract]
# 4   Share of other comprehensive income of associa...  포괄손익계산서 [abstract]
# 5   Other comprehensive income, net of tax, gains ...  포괄손익계산서 [abstract]
# 6   Other comprehensive income that will be reclas...  포괄손익계산서 [abstract]
# 7   Gains (losses) on remeasuring available-for-sa...  포괄손익계산서 [abstract]
# 8   Share of other comprehensive income of associa...  포괄손익계산서 [abstract]
# 9   Gains (losses) on exchange differences on tran...  포괄손익계산서 [abstract]
# 10     Gains (losses) on cash flow hedges, net of tax  포괄손익계산서 [abstract]
# 11                         Total comprehensive income  포괄손익계산서 [abstract]
# 12  Comprehensive income, attributable to owners o...  포괄손익계산서 [abstract]
# 13  Comprehensive income, attributable to non-cont...  포괄손익계산서 [abstract]
#
#                                                                        \
#        class1                      class2                      class3
# 0   당기순이익(손실)                        None                        None
# 1      기타포괄손익                        None                        None
# 2      기타포괄손익  후속적으로 당기손익으로 재분류되지 않는 포괄손익                        None
# 3      기타포괄손익  후속적으로 당기손익으로 재분류되지 않는 포괄손익         기타포괄손익-공정가치금융자산평가손익
# 4      기타포괄손익  후속적으로 당기손익으로 재분류되지 않는 포괄손익  관계기업 및 공동기업의 기타포괄손익에 대한 지분
# 5      기타포괄손익  후속적으로 당기손익으로 재분류되지 않는 포괄손익               순확정급여부채 재측정요소
# 6      기타포괄손익     후속적으로 당기손익으로 재분류되는 포괄손익                        None
# 7      기타포괄손익     후속적으로 당기손익으로 재분류되는 포괄손익                매도가능금융자산평가손익
# 8      기타포괄손익     후속적으로 당기손익으로 재분류되는 포괄손익  관계기업 및 공동기업의 기타포괄손익에 대한 지분
# 9      기타포괄손익     후속적으로 당기손익으로 재분류되는 포괄손익                 해외사업장환산외환차이
# 10     기타포괄손익     후속적으로 당기손익으로 재분류되는 포괄손익            현금흐름위험회피파생상품평가손익
# 11      총포괄손익                        None                        None
# 12   포괄손익의 귀속                  지배기업 소유주지분                        None
# 13   포괄손익의 귀속                       비지배지분                        None
#
#       20190101-20191231    20180101-20181231    20170101-20171231  \
#               (연결재무제표,)            (연결재무제표,)            (연결재무제표,)
# 0  21,738,865,000,000.0 44,344,857,000,000.0 42,186,747,000,000.0
# 1   3,016,194,000,000.0    -12,242,000,000.0 -5,502,257,000,000.0
# 2     -50,765,000,000.0   -656,647,000,000.0    407,900,000,000.0
# 3   1,146,599,000,000.0   -235,865,000,000.0                  nan
# 4     -16,896,000,000.0    -10,631,000,000.0     -6,347,000,000.0
# 5  -1,180,468,000,000.0   -410,151,000,000.0    414,247,000,000.0
# 6   3,066,959,000,000.0    644,405,000,000.0 -5,910,157,000,000.0
# 7                   nan                  nan    511,207,000,000.0
# 8      48,649,000,000.0      6,688,000,000.0    -49,256,000,000.0
# 9   3,016,499,000,000.0    590,638,000,000.0 -6,334,987,000,000.0
# 10      1,811,000,000.0     47,079,000,000.0    -37,121,000,000.0
# 11 24,755,059,000,000.0 44,332,615,000,000.0 36,684,490,000,000.0
# 12 24,466,985,000,000.0 43,882,473,000,000.0 35,887,505,000,000.0
# 13    288,074,000,000.0    450,142,000,000.0    796,985,000,000.0
#
#       20160101-20161231
#               (연결재무제표,)
# 0  22,726,092,000,000.0
# 1   1,991,400,000,000.0
# 2   1,014,040,000,000.0
# 3                  None
# 4      50,438,000,000.0
# 5     963,602,000,000.0
# 6     977,360,000,000.0
# 7     -23,839,000,000.0
# 8    -130,337,000,000.0
# 9   1,131,536,000,000.0
# 10
# 11 24,717,492,000,000.0
# 12 24,310,814,000,000.0
# 13    406,678,000,000.0

# %%
fs[3]#현금흐름표
# Out:
#    [D520000] Statement of cash flows, indirect method - Consolidated financial statements (Unit: KRW)  \
#                                                                                            concept_id
# 0    ifrs-full_CashFlowsFromUsedInOperatingActivities
# 1   entity00126380_udf_CF_201710211099539_CashFlow...
# 2   entity00126380_udf_CF_201710211092510_udf_CF_2...
# 3   entity00126380_udf_CF_2017102110929616_udf_CF_...
# 4   entity00126380_udf_CF_2017102110934928_udf_CF_...
# 5   ifrs-full_InterestReceivedClassifiedAsOperatin...
# 6   ifrs-full_InterestPaidClassifiedAsOperatingAct...
# 7   ifrs-full_DividendsReceivedClassifiedAsOperati...
# 8   ifrs-full_IncomeTaxesPaidRefundClassifiedAsOpe...
# 9    ifrs-full_CashFlowsFromUsedInInvestingActivities
# 10  entity00126380_udf_CF_2017102110167395_CashFlo...
# 11  entity00126380_udf_CF_201987152650384_CashFlow...
# 12  entity00126380_udf_CF_2019726153251267_CashFlo...
# 13  entity00126380_udf_CF_2020210125720111_CashFlo...
# 14  dart_ProceedsFromSalesOfLongTermFinancialInstr...
# 15        dart_PurchaseOfLongTermFinancialInstruments
# 16  entity00126380_udf_CF_202021013058237_CashFlow...
# 17  entity00126380_udf_CF_2020210125811828_CashFlo...
# 18       dart_PurchaseOfFinancialAssetsHeldToMaturity
# 19  entity00126380_udf_CF_201972615318915_CashFlow...
# 20  entity00126380_udf_CF_2018510204028298_CashFlo...
# 21  entity00126380_udf_CF_2018510204038291_CashFlo...
# 22  entity00126380_udf_CF_2018510204040276_CashFlo...
# 23  entity00126380_udf_CF_2018510204036276_CashFlo...
# 24  entity00126380_udf_CF_2018510204025664_CashFlo...
# 25  entity00126380_udf_CF_20171021101629105_CashFl...
# 26  entity00126380_udf_CF_20171021101629633_CashFl...
# 27  ifrs-full_ProceedsFromSalesOfPropertyPlantAndE...
# 28  ifrs-full_PurchaseOfPropertyPlantAndEquipmentC...
# 29  ifrs-full_ProceedsFromSalesOfIntangibleAssetsC...
# 30  ifrs-full_PurchaseOfIntangibleAssetsClassified...
# 31  entity00126380_udf_CF_20171021101626447_CashFl...
# 32  entity00126380_udf_CF_202021013532484_CashFlow...
# 33  entity00126380_udf_CF_20171021101625672_CashFl...
# 34   ifrs-full_CashFlowsFromUsedInFinancingActivities
# 35  entity00126380_udf_CF_20171021102249949_CashFl...
# 36                   dart_AcquisitionOfTreasuryShares
# 37                dart_ProceedsFromLongTermBorrowings
# 38                dart_RepaymentsOfLongTermBorrowings
# 39  ifrs-full_DividendsPaidClassifiedAsFinancingAc...
# 40  entity00126380_udf_CF_20171021102253395_CashFl...
# 41  ifrs-full_EffectOfExchangeRateChangesOnCashAnd...
# 42  ifrs-full_IncreaseDecreaseInCashAndCashEquival...
# 43   dart_CashAndCashEquivalentsAtBeginningOfPeriodCf
# 44         dart_CashAndCashEquivalentsAtEndOfPeriodCf
#
#                               \
#                     label_ko
# 0                  영업활동 현금흐름
# 1              영업에서 창출된 현금흐름
# 2                      당기순이익
# 3                         조정
# 4         영업활동으로 인한 자산부채의 변동
# 5                     이자의 수취
# 6                     이자의 지급
# 7                     배당금 수입
# 8                    법인세 납부액
# 9                  투자활동 현금흐름
# 10           단기금융상품의 순감소(증가)
# 11      단기상각후원가금융자산의 순감소(증가)
# 12  단기당기손익-공정가치금융자산의 순감소(증가)
# 13            단기매도가능금융자산의 처분
# 14                장기금융상품의 처분
# 15                장기금융상품의 취득
# 16            장기매도가능금융자산의 처분
# 17            장기매도가능금융자산의 취득
# 18              만기보유금융자산의 취득
# 19             상각후원가금융자산의 처분
# 20             상각후원가금융자산의 취득
# 21       기타포괄손익-공정가치금융자산의 처분
# 22       기타포괄손익-공정가치금융자산의 취득
# 23         당기손익-공정가치금융자산의 처분
# 24         당기손익-공정가치금융자산의 취득
# 25        관계기업 및 공동기업 투자의 처분
# 26        관계기업 및 공동기업 투자의 취득
# 27                  유형자산의 처분
# 28                  유형자산의 취득
# 29                  무형자산의 처분
# 30                  무형자산의 취득
# 31           사업결합으로 인한 현금유출액
# 32            사업양도로 인한 현급유입액
# 33        기타투자활동으로 인한 현금유출입액
# 34                 재무활동 현금흐름
# 35            단기차입금의 순증가(감소)
# 36                  자기주식의 취득
# 37                 장기차입금의 차입
# 38            사채 및 장기차입금의 상환
# 39                   배당금의 지급
# 40                 비지배지분의 증감
# 41          외화환산으로 인한 현금의 변동
# 42             현금및현금성자산의 순증감
# 43              기초의 현금및현금성자산
# 44              기말의 현금및현금성자산
#
#                                                                          \
#                                              label_en            class0
# 0      Cash flows from (used in) operating activities  현금흐름표 [abstract]
# 1                Cash flows from operating activities  현금흐름표 [abstract]
# 2                                              Profit  현금흐름표 [abstract]
# 3                                         Adjustments  현금흐름표 [abstract]
# 4   NEWAccount for Cash flows from operating activ...  현금흐름표 [abstract]
# 5                                   Interest received  현금흐름표 [abstract]
# 6                                       Interest paid  현금흐름표 [abstract]
# 7                                  Dividends received  현금흐름표 [abstract]
# 8                          Income taxes paid (refund)  현금흐름표 [abstract]
# 9      Cash flows from (used in) investing activities  현금흐름표 [abstract]
# 10  Net outflow in financial assets at fair value ...  현금흐름표 [abstract]
# 11  Net increase of financial assets measured at a...  현금흐름표 [abstract]
# 12  Net decrease of short-term financial assets at...  현금흐름표 [abstract]
# 13  the disposal of Available-for-sale financial a...  현금흐름표 [abstract]
# 14  Proceeds from sales of long-term financial ins...  현금흐름표 [abstract]
# 15        Purchase of long-term financial instruments  현금흐름표 [abstract]
# 16  Proceeds from sales of non-current available-f...  현금흐름표 [abstract]
# 17     Purchase of non-current available-for-sale f/s  현금흐름표 [abstract]
# 18  Proceeds from sales of maturity-holding securi...  현금흐름표 [abstract]
# 19  Disposal of Financial Assets Measured at Amort...  현금흐름표 [abstract]
# 20  Purchase of Financial Assets Measured at Amort...  현금흐름표 [abstract]
# 21  Proceeds from disposal of fair value assessmen...  현금흐름표 [abstract]
# 22  Proceeds from acquisition of fair value assess...  현금흐름표 [abstract]
# 23  Proceeds from disposal of fair value assessmen...  현금흐름표 [abstract]
# 24  Proceeds from acquisition of fair value assess...  현금흐름표 [abstract]
# 25  Proceeds from disposal of associates and joint...  현금흐름표 [abstract]
# 26  Acquisition from disposal of associates and jo...  현금흐름표 [abstract]
# 27  Proceeds from sales of property, plant and equ...  현금흐름표 [abstract]
# 28          Purchase of property, plant and equipment  현금흐름표 [abstract]
# 29           Proceeds from sales of intangible assets  현금흐름표 [abstract]
# 30                      Purchase of intangible assets  현금흐름표 [abstract]
# 31             Net Cashflow from Business combination  현금흐름표 [abstract]
# 32        Net Cashflow from Business combination(out)  현금흐름표 [abstract]
# 33                                             Others  현금흐름표 [abstract]
# 34     Cash flows from (used in) financing activities  현금흐름표 [abstract]
# 35   Net proceeds(repayment of) short-term borrowings  현금흐름표 [abstract]
# 36                     Acquisition of treasury shares  현금흐름표 [abstract]
# 37                 Proceeds from long term borrowings  현금흐름표 [abstract]
# 38                 Repayments of long term borrowings  현금흐름표 [abstract]
# 39                                     Dividends paid  현금흐름표 [abstract]
# 40                                 Minority interests  현금흐름표 [abstract]
# 41  Effect of exchange rate changes on cash and ca...  현금흐름표 [abstract]
# 42  Net increase (decrease) in cash and cash equiv...  현금흐름표 [abstract]
# 43   Cash and cash equivalents at beginning of period  현금흐름표 [abstract]
# 44         Cash and cash equivalents at end of period  현금흐름표 [abstract]
#
#                                                                     \
#               class1                    class2              class3
# 0          영업활동 현금흐름                      None                None
# 1          영업활동 현금흐름             영업에서 창출된 현금흐름                None
# 2          영업활동 현금흐름             영업에서 창출된 현금흐름               당기순이익
# 3          영업활동 현금흐름             영업에서 창출된 현금흐름                  조정
# 4          영업활동 현금흐름             영업에서 창출된 현금흐름  영업활동으로 인한 자산부채의 변동
# 5          영업활동 현금흐름                    이자의 수취                None
# 6          영업활동 현금흐름                    이자의 지급                None
# 7          영업활동 현금흐름                    배당금 수입                None
# 8          영업활동 현금흐름                   법인세 납부액                None
# 9          투자활동 현금흐름                      None                None
# 10         투자활동 현금흐름           단기금융상품의 순감소(증가)                None
# 11         투자활동 현금흐름      단기상각후원가금융자산의 순감소(증가)                None
# 12         투자활동 현금흐름  단기당기손익-공정가치금융자산의 순감소(증가)                None
# 13         투자활동 현금흐름            단기매도가능금융자산의 처분                None
# 14         투자활동 현금흐름                장기금융상품의 처분                None
# 15         투자활동 현금흐름                장기금융상품의 취득                None
# 16         투자활동 현금흐름            장기매도가능금융자산의 처분                None
# 17         투자활동 현금흐름            장기매도가능금융자산의 취득                None
# 18         투자활동 현금흐름              만기보유금융자산의 취득                None
# 19         투자활동 현금흐름             상각후원가금융자산의 처분                None
# 20         투자활동 현금흐름             상각후원가금융자산의 취득                None
# 21         투자활동 현금흐름       기타포괄손익-공정가치금융자산의 처분                None
# 22         투자활동 현금흐름       기타포괄손익-공정가치금융자산의 취득                None
# 23         투자활동 현금흐름         당기손익-공정가치금융자산의 처분                None
# 24         투자활동 현금흐름         당기손익-공정가치금융자산의 취득                None
# 25         투자활동 현금흐름        관계기업 및 공동기업 투자의 처분                None
# 26         투자활동 현금흐름        관계기업 및 공동기업 투자의 취득                None
# 27         투자활동 현금흐름                  유형자산의 처분                None
# 28         투자활동 현금흐름                  유형자산의 취득                None
# 29         투자활동 현금흐름                  무형자산의 처분                None
# 30         투자활동 현금흐름                  무형자산의 취득                None
# 31         투자활동 현금흐름           사업결합으로 인한 현금유출액                None
# 32         투자활동 현금흐름            사업양도로 인한 현급유입액                None
# 33         투자활동 현금흐름        기타투자활동으로 인한 현금유출입액                None
# 34         재무활동 현금흐름                      None                None
# 35         재무활동 현금흐름            단기차입금의 순증가(감소)                None
# 36         재무활동 현금흐름                  자기주식의 취득                None
# 37         재무활동 현금흐름                 장기차입금의 차입                None
# 38         재무활동 현금흐름            사채 및 장기차입금의 상환                None
# 39         재무활동 현금흐름                   배당금의 지급                None
# 40         재무활동 현금흐름                 비지배지분의 증감                None
# 41  외화환산으로 인한 현금의 변동                      None                None
# 42     현금및현금성자산의 순증감                      None                None
# 43      기초의 현금및현금성자산                      None                None
# 44      기말의 현금및현금성자산                      None                None
#
#        20190101-20191231     20180101-20181231     20170101-20171231  \
#                (연결재무제표,)             (연결재무제표,)             (연결재무제표,)
# 0   45,382,915,000,000.0  67,031,863,000,000.0  62,162,041,000,000.0
# 1   56,635,791,000,000.0  78,025,064,000,000.0  67,777,432,000,000.0
# 2   21,738,865,000,000.0  44,344,857,000,000.0  42,186,747,000,000.0
# 3   37,442,682,000,000.0  43,604,573,000,000.0  36,211,232,000,000.0
# 4   -2,545,756,000,000.0  -9,924,366,000,000.0 -10,620,547,000,000.0
# 5    2,306,401,000,000.0   1,788,520,000,000.0   1,581,117,000,000.0
# 6      579,979,000,000.0     548,272,000,000.0     542,715,000,000.0
# 7      241,801,000,000.0     215,992,000,000.0     173,305,000,000.0
# 8   13,221,099,000,000.0  12,449,441,000,000.0   6,827,098,000,000.0
# 9  -39,948,171,000,000.0 -52,240,453,000,000.0 -49,385,216,000,000.0
# 10  -2,030,913,000,000.0 -12,368,298,000,000.0     387,627,000,000.0
# 11    -818,089,000,000.0  -1,436,844,000,000.0                   nan
# 12     374,982,000,000.0    -139,668,000,000.0                   nan
# 13                   nan                   nan     499,856,000,000.0
# 14   4,586,610,000,000.0     255,850,000,000.0   1,750,221,000,000.0
# 15  12,725,465,000,000.0   7,678,654,000,000.0   1,079,355,000,000.0
# 16                   nan                   nan     191,826,000,000.0
# 17                   nan                   nan    -358,497,000,000.0
# 18                   nan                   nan     106,751,000,000.0
# 19     694,584,000,000.0                   nan                   nan
# 20    -825,027,000,000.0    -158,716,000,000.0                   nan
# 21       1,575,000,000.0      16,211,000,000.0                   nan
# 22     -63,773,000,000.0    -456,134,000,000.0                   nan
# 23      64,321,000,000.0      80,138,000,000.0                   nan
# 24    -135,826,000,000.0    -193,848,000,000.0                   nan
# 25      12,149,000,000.0         148,000,000.0     355,926,000,000.0
# 26     -12,778,000,000.0     -51,226,000,000.0     -25,293,000,000.0
# 27     513,265,000,000.0     556,973,000,000.0     308,354,000,000.0
# 28  25,367,756,000,000.0  29,556,406,000,000.0  42,792,234,000,000.0
# 29       7,241,000,000.0      11,935,000,000.0         733,000,000.0
# 30   3,249,914,000,000.0   1,020,517,000,000.0     983,740,000,000.0
# 31  -1,019,405,000,000.0     -99,108,000,000.0  -8,754,268,000,000.0
# 32                   nan                   nan   1,248,834,000,000.0
# 33      46,048,000,000.0      -2,289,000,000.0     -28,455,000,000.0
# 34  -9,484,510,000,000.0 -15,090,222,000,000.0 -12,560,867,000,000.0
# 35     865,792,000,000.0  -2,046,470,000,000.0   2,730,676,000,000.0
# 36                   nan     875,111,000,000.0   8,350,424,000,000.0
# 37                   nan       3,580,000,000.0     998,311,000,000.0
# 38     709,400,000,000.0   1,986,597,000,000.0   1,140,803,000,000.0
# 39   9,639,202,000,000.0  10,193,695,000,000.0   6,804,297,000,000.0
# 40      -1,700,000,000.0       8,071,000,000.0       5,670,000,000.0
# 41     595,260,000,000.0      94,187,000,000.0  -1,782,270,000,000.0
# 42  -3,454,506,000,000.0    -204,625,000,000.0  -1,566,312,000,000.0
# 43  30,340,505,000,000.0  30,545,130,000,000.0  32,111,442,000,000.0
# 44  26,885,999,000,000.0  30,340,505,000,000.0  30,545,130,000,000.0
#
#        20160101-20161231
#                (연결재무제표,)
# 0   47,385,644,000,000.0
# 1   52,299,610,000,000.0
# 2   22,726,092,000,000.0
# 3   30,754,471,000,000.0
# 4   -1,180,953,000,000.0
# 5    1,405,085,000,000.0
# 6     -443,838,000,000.0
# 7      256,851,000,000.0
# 8   -6,132,064,000,000.0
# 9  -29,658,675,000,000.0
# 10  -6,780,610,000,000.0
# 11                  None
# 12                  None
# 13   3,010,003,000,000.0
# 14     789,862,000,000.0
# 15  -1,741,547,000,000.0
# 16   2,010,356,000,000.0
# 17  -1,498,148,000,000.0
# 18                  None
# 19                  None
# 20                  None
# 21                  None
# 22                  None
# 23                  None
# 24                  None
# 25   2,280,203,000,000.0
# 26     -84,306,000,000.0
# 27     270,874,000,000.0
# 28 -24,142,973,000,000.0
# 29       6,944,000,000.0
# 30  -1,047,668,000,000.0
# 31    -622,050,000,000.0
# 32
# 33      19,936,000,000.0
# 34  -8,669,514,000,000.0
# 35   1,351,037,000,000.0
# 36  -7,707,938,000,000.0
# 37   1,041,743,000,000.0
# 38    -252,846,000,000.0
# 39  -3,114,742,000,000.0
# 40      13,232,000,000.0
# 41     417,243,000,000.0
# 42   9,474,698,000,000.0
# 43  22,636,744,000,000.0
# 44  32,111,442,000,000.0
